# %%
##SCRAPING CODES

#1.GOOGLE SCHOLAR: 
#This code extract data from HTML pages
#Consider selecting keywords carefully, as the code can break if you abuse it too many times in one day.
#2.PUBMED
#You need install pymed libraries
#3.SCOPUS
##Note: to use scopus you must have acces first.
#You can use my APIKey, otherwise first you have to access Elsevier and create an APIKey.
#consider that in Scopus there is a maximum number of papers that you can register also

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from urllib.parse import quote
from datetime import datetime



# determine key words

search_terms1 = ["roots AND phenology", "belowground AND phenology","roots AND growth",'"roots production"']

# List of keywords to exclude (tittle or abstract)
exclude_keywords = [
    "animals", "human", "diseases", "insects"
]  

# Parameters
pages = 30   # Number of pages to scrape per search term
delay = 30  # Delay in seconds between page requests (try not to go below 20 seconds!)

def google_scholar_screening(search_terms, exclude_keywords, pages=3, delay=10):
    base_url = "https://scholar.google.com/scholar"
    all_results = []

    for term in search_terms: #loop for each keyword
        query = quote(term)
        print(f"Starting search for: {term}")

        for page in range(pages):
            start = page * 10
            url = f"{base_url}?q={query}&start={start}"
            print(f"Fetching: {url}")

            # Simulate browser user-agent to reduce blocking risk
            headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
            }

            try:
                response = requests.get(url, headers=headers)
                response.raise_for_status()
                webpage = BeautifulSoup(response.text, "html.parser")
            except requests.RequestException as e:
                print(f"Failed to fetch page: {url}")
                print(e)
                continue

            # Extract article details
            #NOTE: gs_ri is the broadest class in the HTML structure and within it are the other classes (gs_rt, gs_rs, gs_a, etc.)
            
            articles = webpage.select(".gs_ri")  # Contenedor de cada artículo
            if not articles:
                print("No articles found on the page. Check the HTML structure.")
                continue

            for article in articles:
                title_elem = article.select_one(".gs_rt a")
                snippet_elem = article.select_one(".gs_rs")
                pub_info_elem = article.select_one(".gs_a")
                cited_by_container = article.select_one(".gs_fl.gs_flb")  # Contenedor de citas

                # Skip if essential elements are missing
                if not title_elem or not snippet_elem or not pub_info_elem:
                    continue

                # Extract title and link
                title = title_elem.text
                link = title_elem["href"]

                # Extract abstract
                abstract = snippet_elem.text

                # Extract publication info (authors, year, journal, editorial)
                pub_info = pub_info_elem.text

                # We consider the format(pattern) to be "authors - journal, year - publisher"
                pub_info_pattern = re.compile(r"^(.*?)\s*-\s*(.*?),\s*(\d{4})\s*-\s*(.*)$")
                match = pub_info_pattern.match(pub_info)

                #Now we get each part of the pattern

                if match:
                    authors = match.group(1).strip()
                    journal = match.group(2).strip()
                    year = int(match.group(3))
                    editorial = match.group(4).strip()
                else:
                    authors = pub_info.strip()
                    journal = ""
                    year = None
                    editorial = ""

                # Extract citations
                citation_count = 0
                if cited_by_container:
                    cited_by_text = cited_by_container.get_text()
                # We search for the words "Cited by" in this part of the HTML content
                    if "Cited by" in cited_by_text or "Cité" in cited_by_text: #or in French!
                        citation_count = int(re.search(r"\d+", cited_by_text).group(0))

                # Print the citation text to verify
                print(f"Citation text for '{title}': {cited_by_text if cited_by_container else 'No citation found'}")

                # Check if keywords are excluded
                exclude_in_title = any(keyword.lower() in title.lower() for keyword in exclude_keywords)
                exclude_in_abstract = any(keyword.lower() in abstract.lower() for keyword in exclude_keywords)

                # Add to results
                if not (exclude_in_title or exclude_in_abstract):
                    all_results.append({
                        "Title": title,
                        "Link": link,
                        "Abstract": abstract,
                        "Authors": authors,
                        "Journal": journal,
                        "Year": year,
                        "Citations": citation_count,
                        "SearchTerm": term
                    })

            # Pause between requests to avoid detection
            time.sleep(delay)

    
    results = pd.DataFrame(all_results)
    return results

# Fetch results
results1 = google_scholar_screening(search_terms1, exclude_keywords, pages, delay)

# Remove duplicate rows (based on the title)
results = results1.drop_duplicates(subset="Title")

# Save results to a CSV file
results.to_csv("ScreepingGoogleScholarPC_mars.csv", index=False)

# Display the results
print(results)
# Out:
# Starting search for: roots AND phenology
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=0
# Failed to fetch page: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=0
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3Droots%2520AND%2520phenology%26start%3D0&q=EgSdiEk6GLP4lr4GIiwv2EU2bMOHvC-r0Yyq_tMvnPC2-MWRuKtje5Ncn1boIYdPS1h5YG8IsWw-XDIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=10
# Citation text for 'Plant phenology: a critical controller of soil resource acquisition': Enregistrer Citer Cité 350 fois Autres articles Les 14 versions
# Citation text for 'The mycorrhizal status, root anatomy, and phenology of plants in a sugar maple forest': Enregistrer Citer Cité 312 fois Autres articles Les 8 versions
# Citation text for 'Root phenology unresponsive to earlier snowmelt despite advanced above‐ground phenology in two subarctic plant communities': Enregistrer Citer Cité 32 fois Autres articles Les 14 versions
# Citation text for 'Soybean root development relative to vegetative and reproductive phenology': Enregistrer Citer Cité 42 fois Autres articles Les 16 versions
# Citation text for 'Root phenology in an Arctic shrub-graminoid community: the effects of long-term warming and herbivore exclusion': Enregistrer Citer Cité 31 fois Autres articles Les 10 versions
# Citation text for 'Changes in fine-root production, phenology and spatial distribution in response to N application in irrigated sweet cherry trees': Enregistrer Citer Cité 35 fois Autres articles Les 10 versions
# Citation text for 'The phenology of fine root growth in a maple-dominated ecosystem: relationships with some soil properties': Enregistrer Citer Cité 80 fois Autres articles Les 14 versions
# Citation text for 'Control of scion vigour by kiwifruit rootstocks is correlated with spring root pressure phenology': Enregistrer Citer Cité 82 fois Autres articles Les 16 versions
# Citation text for 'Phenology of roots and mycorrhiza in orchid species differing in phototrophic strategy': Enregistrer Citer Cité 126 fois Autres articles Les 15 versions
# Citation text for 'Synchronous and asynchronous root and shoot phenology in temperate woody seedlings': Enregistrer Citer Cité 26 fois Autres articles Les 8 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=20
# Citation text for 'Limited linkages of aboveground and belowground phenology: a study in grape': Enregistrer Citer Cité 24 fois Autres articles Les 8 versions
# Citation text for 'Autumnal warming does not change root phenology in two contrasting vegetation types of subarctic tundra': Enregistrer Citer Cité 24 fois Autres articles Les 14 versions
# Citation text for 'On the sensitivity of root and leaf phenology to warming in the Arctic': Enregistrer Citer Cité 14 fois Autres articles Les 9 versions
# Citation text for 'Leaf and root phenology and biomass of Eriophorum vaginatum in response to warming in the Arctic': Enregistrer Citer Cité 14 fois Autres articles Les 7 versions
# Citation text for 'Root growth phenology, anatomy, and morphology among root orders in Vaccinium macrocarpon Ait.': Enregistrer Citer Cité 9 fois Autres articles Les 9 versions
# Citation text for 'Seasonal pattern of root growth in relation to shoot phenology and soil temperature in sweet cherry trees (Prunus avium): A preliminary study in central Chile': Enregistrer Citer Cité 24 fois Autres articles Les 14 versions  Version HTML
# Citation text for 'Soil warming alters fine root lifespan, phenology, and architecture in a Cunninghamia lanceolata plantation': Enregistrer Citer Cité 23 fois Autres articles Les 3 versions
# Citation text for 'Improving root-zone soil moisture estimations using dynamic root growth and crop phenology': Enregistrer Citer Cité 15 fois Autres articles Les 4 versions
# Citation text for 'Seasonal patterns of root growth in relation to shoot phenology in grape and apple': Enregistrer Citer Cité 69 fois Autres articles Les 5 versions
# Citation text for 'Fine root phenology differs among subtropical evergreen broadleaved forests with increasing tree diversities': Enregistrer Citer Cité 13 fois Autres articles Les 6 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=30
# Citation text for 'Phenology of fine root and shoot using high frequency temporal resolution images in a temperate larch forest': Enregistrer Citer Cité 8 fois Autres articles Les 10 versions
# Citation text for 'Response of the fine root production, phenology, and turnover rate of six shrub species from a subtropical forest to a soil moisture gradient and shading': Enregistrer Citer Cité 26 fois Autres articles Les 11 versions
# Citation text for 'From Roots to Leaves: Tree Growth Phenology in Forest Ecosystems': Enregistrer Citer Autres articles
# Citation text for 'Warming nondormant tree roots advances aboveground spring phenology in temperate trees': Enregistrer Citer Cité 9 fois Autres articles Les 14 versions
# Citation text for 'Root Growth Phenology, Root Longevity, and Rhizosphere Respiration of Field GrownMutsu'Apple Trees onMalling 9'Rootstock': Enregistrer Citer Cité 64 fois Autres articles Les 5 versions  Version HTML
# Citation text for 'Patterns and drivers in spring and autumn phenology differ above-and belowground in four ecosystems under the same macroclimatic conditions': Enregistrer Citer Cité 11 fois Autres articles Les 11 versions
# Citation text for 'Linking above-and belowground phenology of hybrid walnut growing along a climatic gradient in temperate agroforestry systems': Enregistrer Citer Cité 17 fois Autres articles Les 14 versions
# Citation text for 'Root and shoot phenology, architecture, and organ properties: an integrated trait network among 44 herbaceous wetland species': Enregistrer Citer Cité 8 fois Autres articles Les 4 versions
# Citation text for 'Root physiology and phenology: the key to transplanting success': Enregistrer Citer Cité 12 fois Autres articles Les 10 versions
# Citation text for 'Above and belowground phenology of four Mediterranean sub-shrubs. Preliminary results on root–shoot competition': Enregistrer Citer Cité 40 fois Autres articles Les 7 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=40
# Citation text for 'Unexpected phenology and lifespan of shallow and deep fine roots of walnut trees grown in a silvoarable Mediterranean agroforestry system': Enregistrer Citer Cité 95 fois Autres articles Les 23 versions
# Citation text for 'Niche differences in phenology and rooting depth promote coexistence with a dominant C4 bunchgrass': Enregistrer Citer Cité 276 fois Autres articles Les 15 versions
# Citation text for 'Effects of warming on fine root phenology of forests: a review': Enregistrer Citer Autres articles Les 2 versions  Version HTML
# Citation text for 'Root longevity and phenology differences between two co‐occurring savanna bunchgrasses with different leaf habits': Enregistrer Citer Cité 43 fois Autres articles Les 11 versions
# Citation text for 'Linking belowground and aboveground phenology in two boreal forests in Northeast China': Enregistrer Citer Cité 45 fois Autres articles Les 11 versions
# Citation text for 'Asynchrony in shoot and root phenological relationships in hybrid walnut': Enregistrer Citer Cité 10 fois Autres articles Les 17 versions
# Citation text for 'How phenology influences physiology in deciduous forest spring ephemerals': Enregistrer Citer Cité 231 fois Autres articles Les 11 versions
# Citation text for 'Seasonal root growth of Scots pine seedlings in relation to shoot phenology, carbohydrate status, and nutrient supply': Enregistrer Citer Cité 78 fois Autres articles Les 12 versions
# Citation text for 'Shoot and root growth phenology of grafted avocado': Enregistrer Citer Cité 20 fois Autres articles Les 3 versions  Version HTML
# Citation text for 'Water relations, shoot and root architecture, and phenology of three co-occurring Banksia species: no evidence for niche differentiation in the pattern of water use': Enregistrer Citer Cité 100 fois Autres articles Les 7 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=50
# Citation text for 'Root-derived respiration and nitrous oxide production as affected by crop phenology and nitrogen fertilization': Enregistrer Citer Cité 71 fois Autres articles Les 18 versions
# Citation text for 'Multifunctions of fine root phenology in vegetative and reproductive growth in mature beech forest ecosystems': Enregistrer Citer Cité 6 fois Autres articles Les 7 versions
# Citation text for 'Coupling carbon allocation with leaf and root phenology predicts tree–grass partitioning along a savanna rainfall gradient': Enregistrer Citer Cité 38 fois Autres articles Les 24 versions  Version HTML
# Citation text for 'Fine root seasonal dynamics, plasticity, and mycorrhization in 2 coexisting Mediterranean oaks with contrasting aboveground phenology': Enregistrer Citer Cité 32 fois Autres articles Les 18 versions
# Citation text for 'Spatial and Temporal Heterogeneity Creates a “Brown Tide” in Root Phenology and Nutrition': Enregistrer Citer Cité 38 fois Autres articles Les 11 versions
# Citation text for 'Vegetation phenology can be captured with digital repeat photography and linked to variability of root nutrition in Hedysarum alpinum': Enregistrer Citer Cité 35 fois Autres articles Les 10 versions
# Citation text for 'Plant phenology and soil fertility effects on below-ground carbon allocation for an annual (Bromus madritensis) and a perennial (Bromus erectus) grass species': Enregistrer Citer Cité 122 fois Autres articles Les 8 versions
# Citation text for 'Exploring fine root growth, phenology, and production in urban trees': Enregistrer Citer Autres articles Les 2 versions  Version HTML
# Citation text for 'Effects of nutrient management and planting systems on root phenology and grain yield of wheat (Triticum aestivum)': Enregistrer Citer Cité 59 fois Autres articles Les 5 versions  Version HTML
# Citation text for 'Prevalence and phenology of fine root endophyte colonization across populations of Lycopodiella inundata': Enregistrer Citer Cité 28 fois Autres articles Les 16 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=60
# Citation text for 'Unaltered phenology but increased production of ectomycorrhizal roots of Pinus elliottii under 4 years of nitrogen addition': Enregistrer Citer Cité 15 fois Autres articles Les 10 versions
# Citation text for 'Digging deep to open the white black box of snow root phenology': Enregistrer Citer Cité 16 fois Autres articles Les 17 versions
# Citation text for 'Phenology, growth, and allocation in global terrestrial productivity': Enregistrer Citer Cité 48 fois Autres articles Les 2 versions
# Citation text for 'Root and shoot phenology and root longevity of Norway spruce saplings grown at different soil temperatures': Enregistrer Citer Cité 9 fois Autres articles Les 16 versions
# Citation text for 'Belowground annual ring growth coordinates with aboveground phenology and timing of carbon storage in two tallgrass prairie forb species': Enregistrer Citer Cité 13 fois Autres articles Les 10 versions
# Citation text for 'Root System, Phenology and Yield of Sunflower in Relation to Nitrogen and Phosphorus': Enregistrer Citer Cité 4 fois Autres articles Les 6 versions
# Citation text for 'Water management and phenology influence the root-associated rice field microbiota': Enregistrer Citer Cité 49 fois Autres articles Les 12 versions
# Citation text for 'Fall fertilization of Holm oak affects N and P dynamics, root growth potential, and post-planting phenology and growth': Enregistrer Citer Cité 69 fois Autres articles Les 14 versions
# Citation text for 'Contrasting phenology of Eucalyptus grandis fine roots in upper and very deep soil layers in Brazil': Enregistrer Citer Cité 31 fois Autres articles Les 19 versions
# Citation text for 'Differences in root phenology and water depletion by an invasive grass explains persistence in a Mediterranean ecosystem': Enregistrer Citer Cité 16 fois Autres articles Les 13 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=70
# Citation text for 'Coordination of spring vascular and organ phenology in deciduous angiosperms growing in seasonally cold climates': Enregistrer Citer Cité 57 fois Autres articles Les 13 versions
# Citation text for 'Linking tree-rooting profiles to leaf phenology: a first attempt on Tectona Grandis Linn F.': Enregistrer Citer Cité 8 fois Autres articles Les 12 versions
# Citation text for 'Soil warming and straw return impacts on winter wheat phenology, photosynthesis, root growth, and grain yield in the North China Plain': Enregistrer Citer Cité 34 fois Autres articles Les 4 versions
# Citation text for 'Temperate and boreal forest tree phenology: from organ-scale processes to terrestrial ecosystem models': Enregistrer Citer Cité 295 fois Autres articles Les 18 versions
# Citation text for 'Implementation of a dynamic rooting depth and phenology into a land surface model: Evaluation of carbon, water, and energy fluxes in the high latitude ecosystems': Enregistrer Citer Cité 23 fois Autres articles Les 8 versions
# Citation text for 'Grape root phenology relative to control of parasitic nematodes': Enregistrer Citer Cité 48 fois Autres articles Les 7 versions
# Citation text for 'Above-and belowground phenology responses of subtropical Chinese fir (Cunninghamia lanceolata) to soil warming, precipitation exclusion and their interaction': Enregistrer Citer Cité 4 fois Autres articles Les 4 versions
# Citation text for 'Responses of root phenology in ecotypes of Eriophorum vaginatum to transplantation and warming in the Arctic': Enregistrer Citer Cité 6 fois Autres articles Les 8 versions
# Citation text for 'Effects of drought on the phenology, growth, and morphological development of three urban tree species and cultivars': Enregistrer Citer Cité 36 fois Autres articles Les 14 versions  En cache
# Citation text for 'Shared quantitative trait loci underlying root biomass and phenology in wheat (Triticum aestivum L.)': Enregistrer Citer Cité 5 fois Autres articles Les 2 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=80
# Citation text for 'Root Phenology in a Changing World': Enregistrer Citer Autres articles Les 2 versions
# Citation text for 'Responses of tree fine roots to temperature': Enregistrer Citer Cité 724 fois Autres articles Les 15 versions
# Citation text for 'Plant phenology and global climate change: Current progresses and challenges': Enregistrer Citer Cité 1561 fois Autres articles Les 12 versions
# Citation text for 'Phenology, litterfall, growth, and root biomass in a tidal floodplain forest in the Amazon estuary': Enregistrer Citer Cité 33 fois Autres articles Les 13 versions  En cache
# Citation text for 'Environmental influences on the phenology of pine': Enregistrer Citer Cité 136 fois Autres articles Les 4 versions
# Citation text for 'Early season root production in relation to leaf production among six diverse temperate tree species': Enregistrer Citer Cité 61 fois Autres articles Les 11 versions
# Citation text for 'Phenology-dependent root bacteria enhance yield of Brassica napus': Enregistrer Citer Cité 18 fois Autres articles Les 4 versions
# Citation text for 'Responses of spring phenology to climate change': Enregistrer Citer Cité 1325 fois Autres articles Les 19 versions
# Citation text for 'Symbiotic N2 fixation activity in relation to C economy of Pisum sativum L. as a function of plant phenology': Enregistrer Citer Cité 143 fois Autres articles Les 17 versions
# Citation text for 'Effects of morphactin and paclobutrazol flowering treatments on shoot and root phenology in mango cv. Kensington Pride': Enregistrer Citer Cité 80 fois Autres articles Les 7 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=90
# Citation text for 'Shifts in Plant Phenology Significantly Affect the Carbon Allocation in Different Plant Organs': Enregistrer Citer Cité 1 fois Autres articles Les 3 versions
# Citation text for 'Root distribution according to phenology in plantain cultivars (Musa AAB), Ecuador': Enregistrer Citer Cité 3 fois Autres articles Les 7 versions  En cache
# Citation text for 'Cryptic phenology in plants: Case studies, implications, and recommendations': Enregistrer Citer Cité 50 fois Autres articles Les 19 versions
# Citation text for 'Biomass, phenology, and growth': Enregistrer Citer Cité 98 fois Autres articles Les 2 versions
# Citation text for 'Relationships of mycorrhizal symbiosis, rooting strategy, and phenology among tallgrass prairie forbs': Enregistrer Citer Cité 152 fois Autres articles Les 7 versions
# Citation text for 'Seasonal environmental variation and plant phenology in arid Patagonia (Argentina)': Enregistrer Citer Cité 189 fois Autres articles Les 9 versions
# Citation text for 'Soil moisture monitoring of the plant root zone by using phenology as context in remote sensing': Enregistrer Citer Cité 5 fois Autres articles Les 5 versions
# Citation text for 'Root-zone temperatures affect phenology of bud break, flower cluster development, shoot extension growth and gas exchange of 'Braeburn' (Malus domestica) apple …': Enregistrer Citer Cité 63 fois Autres articles Les 13 versions
# Citation text for 'Mycorrhizal infection, phosphorus uptake, and phenology in Ranunculus adoneus: implications for the functioning of mycorrhizae in alpine systems': Enregistrer Citer Cité 172 fois Autres articles Les 13 versions
# Citation text for 'Phenology, morphology, physiology.': Enregistrer Citer Cité 124 fois Autres articles Les 2 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=100
# Citation text for 'Rhizosphere effects on decomposition: controls of plant species, phenology, and fertilization': Enregistrer Citer Cité 410 fois Autres articles Les 11 versions
# Citation text for 'Rhizosphere respiration varies with plant species and phenology: a greenhouse pot experiment': Enregistrer Citer Cité 133 fois Autres articles Les 12 versions
# Citation text for 'Microbial effects on plant phenology and fitness': Enregistrer Citer Cité 45 fois Autres articles Les 13 versions
# Citation text for 'Shoot growth phenology, dry matter distribution and root: shoot ratios of provenances of Populus trichocarpa, Picea sitchensis and Pinus contorta growing in …': Enregistrer Citer Cité 109 fois Autres articles Les 4 versions  Version HTML
# Citation text for 'A parameterization of leaf phenology for the terrestrial ecosystem component of climate models': Enregistrer Citer Cité 458 fois Autres articles Les 9 versions
# Citation text for 'A sub-canopy structure for simulating oil palm in the Community Land Model (CLM-Palm): phenology, allocation and yield': Enregistrer Citer Cité 59 fois Autres articles Les 26 versions  Version HTML
# Citation text for 'A severe drought: impact on tree growth, phenology, net photosynthetic rate and water relations': Enregistrer Citer Cité 151 fois Autres articles Les 3 versions
# Citation text for 'Phenology, roots and reproductive allocation, but not the LHS scheme, shape ecotypes along an aridity gradient': Enregistrer Citer Cité 20 fois Autres articles Les 5 versions
# Citation text for 'Soil moisture controls on phenology and productivity in a semi-arid critical zone': Enregistrer Citer Cité 115 fois Autres articles Les 12 versions
# Citation text for 'Temperature dependent models to predict regional differences in corn rootworm (Coleoptera: Chrysomelidae) phenology': Enregistrer Citer Cité 68 fois Autres articles Les 6 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=110
# Citation text for 'Maize phenology alters the distribution of enzyme activities in soil: Field estimates': Enregistrer Citer Cité 26 fois Autres articles Les 15 versions
# Citation text for 'Annual Q10 of soil respiration reflects plant phenological patterns as well as temperature sensitivity': Enregistrer Citer Cité 583 fois Autres articles Les 7 versions
# Citation text for 'Propagating trembling aspen from root cuttings: impact of storage length and phenological period of root donor plants': Enregistrer Citer Cité 39 fois Autres articles Les 12 versions
# Citation text for 'Developmental stages (phenology)': Enregistrer Citer Cité 78 fois Autres articles
# Citation text for 'Fructan Variations in Tuberous Roots of Viguiera discolor Baker (Asteraceae): the Influence of Phenology': Enregistrer Citer Cité 42 fois Autres articles Les 6 versions
# Citation text for 'Environmental Sensitivity and Impact of Climate Change on leaf-, wood-and root Phenology for the Overstory and Understory of Temperate Deciduous Forests': Enregistrer Citer Autres articles Les 4 versions
# Citation text for 'Seasonal asynchrony in above-and below-ground phenology in a temperate forest: Carbon allocation trade-off and plant-microbe interactions': Enregistrer Citer Cité 7 fois Autres articles Les 4 versions
# Citation text for 'The phenology, growth and ecosystem dynamics of Erythronium americanum in the northern hardwood forest': Enregistrer Citer Cité 193 fois Autres articles Les 9 versions
# Citation text for 'Effects of defoliatingStipa tenuisandPiptochaetium napostaenseat different phenological stages: root growth': Enregistrer Citer Cité 39 fois Autres articles Les 6 versions
# Citation text for 'Phenological mismatches between above-and belowground plant responses to climate warming': Enregistrer Citer Cité 98 fois Autres articles Les 15 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=120
# Citation text for 'Phenotyping methods and phenological stages to quantify the root system of common bean': Enregistrer Citer Cité 2 fois Autres articles Les 4 versions  En cache
# Citation text for 'The effect of nitrogen fertilization on the phenology of roots in a barrier island sand dune community': Enregistrer Citer Cité 28 fois Autres articles Les 10 versions
# Citation text for 'How changes in spring and autumn phenology translate into growth‐experimental evidence of asymmetric effects': Enregistrer Citer Cité 23 fois Autres articles Les 8 versions
# Citation text for 'Factors controlling the timing of root elongation intensity in a mature upland oak stand': Enregistrer Citer Cité 150 fois Autres articles Les 13 versions
# Citation text for 'Phenology, resource allocation, and growth of arctic vascular plants': Enregistrer Citer Cité 163 fois Autres articles
# Citation text for 'Seasonal dynamics of non-structural carbohydrates in two species of Mediterranean sub-shrubs with different leaf phenology': Enregistrer Citer Cité 141 fois Autres articles Les 8 versions
# Citation text for 'Host phenology and potential saprotrophism of ectomycorrhizal fungi in the boreal forest': Enregistrer Citer Cité 33 fois Autres articles Les 5 versions
# Citation text for 'Phenology and ecophysiology of tropical trees: Erythrina poeppigiana OF Cook': Enregistrer Citer Cité 248 fois Autres articles Les 7 versions
# Citation text for 'Plant physiognomy, phenology and demography': Enregistrer Citer Cité 85 fois Autres articles  Version HTML
# Citation text for 'Plant phenology and genetic variability in root and nodule development strongly influence genetic structuring of Rhizobium leguminosarum biovar viciae populations …': Enregistrer Citer Cité 75 fois Autres articles Les 9 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=130
# Citation text for 'Genotypic variation in biomass allocation in response to field drought has a greater affect on yield than gas exchange or phenology': Enregistrer Citer Cité 40 fois Autres articles Les 16 versions
# Citation text for 'Timing treatments to the phenology of root carbohydrate reserves to control woody invasive plants': Enregistrer Citer Cité 38 fois Autres articles Les 5 versions
# Citation text for 'Impact of water deficit stress in maize: Phenology and yield components': Enregistrer Citer Cité 324 fois Autres articles Les 9 versions
# Citation text for 'Distinct patterns of below-and aboveground growth phenology and litter carbon inputs along a boreal site type gradient': Enregistrer Citer Cité 20 fois Autres articles Les 15 versions
# Citation text for 'Phenology and function in lycopod–Mucoromycotina symbiosis': Enregistrer Citer Cité 18 fois Autres articles Les 16 versions
# Citation text for 'Effect of early cane pruning on yield components, grape composition, carbohydrates storage and phenology in Vitis vinifera L. cv. Merlot': Enregistrer Citer Cité 16 fois Autres articles Les 8 versions  En cache
# Citation text for 'Prolonged soil frost affects hydraulics and phenology of apple trees': Enregistrer Citer Cité 20 fois Autres articles Les 7 versions  En cache
# Citation text for 'Intra-annual variation of root-associated fungi of Pinus sylvestris var. Mongolica: the role of climate and implications for host phenology': Enregistrer Citer Cité 9 fois Autres articles Les 4 versions
# Citation text for 'Dynamics of phreatophyte root growth relative to a seasonally fluctuating water table in a Mediterranean-type environment': Enregistrer Citer Cité 61 fois Autres articles Les 16 versions
# Citation text for 'Improving the representation of roots in terrestrial models': Enregistrer Citer Cité 138 fois Autres articles Les 15 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=140
# Citation text for 'Understanding and modeling the effect of temperature and daylength on soybean phenology under high-yield conditions': Enregistrer Citer Cité 321 fois Autres articles Les 19 versions
# Citation text for 'A crop phenology detection method using time-series MODIS data': Enregistrer Citer Cité 1182 fois Autres articles Les 11 versions
# Citation text for 'Dry-season leaf flushing of Enterolobium cyclocarpum (ear-pod tree): above- and belowground phenology and water relations': Enregistrer Citer Cité 46 fois Autres articles Les 16 versions
# Citation text for 'Optimizing reproductive phenology in a two-resource world: a dynamic allocation model of plant growth predicts later reproduction in phosphorus-limited plants': Enregistrer Citer Cité 49 fois Autres articles Les 15 versions
# Citation text for 'Productive phenology of tropical montane forests: fertilization experiments along a moisture gradient': Enregistrer Citer Cité 39 fois Autres articles Les 14 versions
# Citation text for 'Using phenology to unravel differential soil water use and productivity in a semiarid savanna': Enregistrer Citer Cité 3 fois Autres articles Les 8 versions
# Citation text for 'Effects of phenology, water availability and seed source on loblolly pine biomass partitioning and transpiration.': Enregistrer Citer Cité 33 fois Autres articles Les 7 versions
# Citation text for 'Methane flux in relation to growth and phenology of a high yielding rice variety as affected by fertilization': Enregistrer Citer Cité 51 fois Autres articles Les 13 versions
# Citation text for 'The effect of grazing on phenology and biomass allocation in Quercus coccifera (L.)': Enregistrer Citer Cité 26 fois Autres articles Les 6 versions
# Citation text for 'Relating the growth phenology and biomass allocation in seedlings of 13 Acadian tree species with their drought tolerance': Enregistrer Citer Cité 8 fois Autres articles Les 4 versions  En cache
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=150
# Citation text for 'Phenology: its importance to the global change community': Enregistrer Citer Cité 524 fois Autres articles Les 8 versions
# Citation text for 'Environmental influence on canopy phenology in the dry tropics': Enregistrer Citer Cité 114 fois Autres articles Les 15 versions
# Citation text for 'Increasing nitrogen availability and soil temperature: effects on xylem phenology and anatomy of mature black spruce': Enregistrer Citer Cité 58 fois Autres articles Les 12 versions
# Citation text for 'Upland rice phenology and nutrient uptake in tropical climate': Enregistrer Citer Cité 24 fois Autres articles Les 9 versions
# Citation text for 'Predicting crop phenology': Enregistrer Citer Cité 285 fois Autres articles Les 5 versions
# Citation text for 'Phenology of sesame': Enregistrer Citer Cité 174 fois Autres articles Les 3 versions  Version HTML
# Citation text for 'Impacts of multiple extreme winter warming events on sub‐Arctic heathland: phenology, reproduction, growth, and CO2 flux responses': Enregistrer Citer Cité 198 fois Autres articles Les 10 versions
# Citation text for 'Temperature dependence of O2 respiration in mangrove leaves and roots: implications for seedling dispersal phenology': Enregistrer Citer Cité 3 fois Autres articles Les 8 versions
# Citation text for 'Composition and seasonal phenology of a nonindigenous root-feeding weevil (Coleoptera: Curculionidae) complex in northern hardwood forests in the Great Lakes …': Enregistrer Citer Cité 37 fois Autres articles Les 16 versions
# Citation text for 'Growth and phenology of eight common weed species': Enregistrer Citer Cité 45 fois Autres articles Les 5 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=160
# Citation text for 'Genome-wide consistent molecular markers associated with phenology, plant production and root traits in diverse rice (Oryza sativa L.) accessions under drought in …': Enregistrer Citer Cité 18 fois Autres articles Les 6 versions
# Citation text for 'An integrated phenology modelling framework in r': Enregistrer Citer Cité 201 fois Autres articles Les 11 versions
# Citation text for 'Dispersal and spatial distribution of western corn rootworm larvae in relation to root phenology.': Enregistrer Citer Cité 16 fois Autres articles Les 5 versions
# Citation text for 'Phenology of glucosinolate concentrations in roots, stems and leaves of Cardamine cordifolia': Enregistrer Citer Cité 25 fois Autres articles Les 5 versions
# Citation text for 'Seasonal trends of Amazonian rainforest phenology, net primary productivity, and carbon allocation': Enregistrer Citer Cité 80 fois Autres articles Les 15 versions
# Citation text for 'Phenology, Pathogenicity and Pathotypes of Cereal Cyst Nematodes, Heterodera a Venae and H. Latipons (Nematoda: Heteroderidae) in Israel': Enregistrer Citer Cité 63 fois Autres articles Les 6 versions  Version HTML
# Citation text for 'The reproductive phenology of Acaena elongata and its relation with arbuscular mycorrhizal fungi': Enregistrer Citer Cité 17 fois Autres articles Les 6 versions
# Citation text for 'Leaf phenological traits in the mangrove Kandelia candel (L.) Druce': Enregistrer Citer Cité 45 fois Autres articles Les 6 versions
# Citation text for 'Phenological pattern of fifteen Mediterranean phanaerophytes from shape Quercus ilex communities of NE-Spain': Enregistrer Citer Cité 156 fois Autres articles Les 14 versions
# Citation text for 'Root:shoot balance controls flush phenology and carbohydrate translocation dynamics in citrus (Citrus x sinensis) trunk': Enregistrer Citer Cité 7 fois Autres articles Les 9 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=170
# Citation text for 'Is temporal variation of soil respiration linked to the phenology of photosynthesis?': Enregistrer Citer Cité 42 fois Autres articles Les 6 versions
# Citation text for 'Linking nutrient dynamics and phenology in Lupinus polyphyllus to identify the right timing for population control': Enregistrer Citer Autres articles
# Citation text for 'Total nonstructural carbohydrate trends in bluebunch wheatgrass related to growth and phenology.': Enregistrer Citer Cité 36 fois Autres articles Les 4 versions  Version HTML
# Citation text for 'Diverse and divergent influences of phenology on herbaceous aboveground biomass across the Tibetan Plateau alpine grasslands': Enregistrer Citer Cité 18 fois Autres articles Les 4 versions
# Citation text for 'Phenology and fungus‐nematode relations of corky root disease of Douglas‐fir': Enregistrer Citer Cité 21 fois Autres articles Les 3 versions
# Citation text for 'Soil temperature dominates forest spring phenology in China': Enregistrer Citer Cité 3 fois Autres articles Les 2 versions
# Citation text for 'Reproductive phenology of the Mediterranean seagrasses Posidonia oceanica (L.) Delile, Cymodocea nodosa (Ucria) Aschers., and Zostera noltii Hornem.': Enregistrer Citer Cité 234 fois Autres articles Les 5 versions
# Citation text for 'Carbohydrate reserve, phenology, and growth cycles of nine Colorado range species.': Enregistrer Citer Cité 124 fois Autres articles Les 5 versions  Version HTML
# Citation text for 'Evaluating heavy metal stress levels in rice based on remote sensing phenology': Enregistrer Citer Cité 18 fois Autres articles Les 9 versions  En cache
# Citation text for 'Mycorrhizal dynamics of three woodland herbs of contrasting phenology along topographic gradients': Enregistrer Citer Cité 43 fois Autres articles Les 4 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=180
# Citation text for 'Novel representation of leaf phenology improves simulation of Amazonian evergreen forest photosynthesis in a land surface model': Enregistrer Citer Cité 58 fois Autres articles Les 20 versions
# Citation text for 'Carbon Allocation into Different Fine-Root Classes of Young Abies alba Trees Is Affected More by Phenology than by Simulated Browsing': Enregistrer Citer Cité 12 fois Autres articles Les 15 versions  En cache
# Citation text for 'Urban vs. natural sugar maple growth: I. Stress symptoms and phenology in relation to site characteristics': Enregistrer Citer Cité 89 fois Autres articles Les 6 versions  En cache
# Citation text for 'Fructose‐containing carbohydrates in the tuberous root of Gomphrena macrocephala St.‐Hil. (Amaranthaceae) at different phenological phases': Enregistrer Citer Cité 64 fois Autres articles Les 6 versions
# Citation text for 'Delayed reproduction in Arabidopsis thaliana improves fitness in soil with suboptimal phosphorus availability': Enregistrer Citer Cité 88 fois Autres articles Les 10 versions
# Citation text for 'Phenology and CO2-assimilation of trees in Central Amazonian floodplains': Enregistrer Citer Cité 93 fois Autres articles Les 12 versions
# Citation text for 'Phenology, physiology and agronomy': Enregistrer Citer Cité 41 fois Autres articles Les 3 versions  Version HTML
# Citation text for 'Diel patterns of autotrophic and heterotrophic respiration among phenological stages': Enregistrer Citer Cité 139 fois Autres articles Les 12 versions
# Citation text for 'Characterization of root and shoot traits in wheat cultivars with putative differences in root system size': Enregistrer Citer Cité 66 fois Autres articles Les 10 versions  En cache
# Citation text for 'Plant phenology: definition, history, and response to environmental factors': Enregistrer Citer Cité 2 fois Autres articles Les 5 versions  Version HTML
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=190
# Citation text for 'Phenology, starch allocation, and environmental effects on Myriophyllum aquaticum': Enregistrer Citer Cité 51 fois Autres articles Les 12 versions
# Citation text for 'Synergistic Effects of Drought Stress and Photoperiods on Phenology and Secondary Metabolism of Silybum marianum': Enregistrer Citer Cité 96 fois Autres articles Les 9 versions
# Citation text for 'Maize phenology affects establishment, damage, and development of the western corn rootworm (Coleoptera: Chrysomelidae)': Enregistrer Citer Cité 41 fois Autres articles Les 14 versions
# Citation text for 'Emerging paradigms of tree phenology in dry tropics': Enregistrer Citer Cité 259 fois Autres articles Les 9 versions
# Citation text for 'Rootstock Scion Interaction and Effects on Vine Vigor, Phenology, and Cold Hardiness of Interspecific Hybrid Grape Cultivars (Vitis spp.)': Enregistrer Citer Cité 28 fois Autres articles Les 7 versions
# Citation text for 'Population density and spatial pattern of Heterodera glycines in relation to soybean phenology': Enregistrer Citer Cité 53 fois Autres articles Les 9 versions
# Citation text for 'Growth, shoot phenology and physiology of diverse seed sources of black spruce: I. Seedling responses to varied atmospheric CO2 concentrations and photoperiods': Enregistrer Citer Cité 66 fois Autres articles Les 11 versions
# Citation text for 'Phenology and morphological diversity of sweet potato (Ipomoea batatas) landraces of the Vale do Ribeira': Enregistrer Citer Cité 87 fois Autres articles Les 15 versions  En cache
# Citation text for 'Hass' avocado carbohydrate fluctuations. I. Growth and phenology': Enregistrer Citer Cité 91 fois Autres articles Les 9 versions  Version HTML
# Citation text for 'The effect of water stress on phenological and ecophysiological characteristics of cheatgrass and Sandberg's bluegrass.': Enregistrer Citer Cité 76 fois Autres articles Les 4 versions  Version HTML
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=200
# Citation text for 'Phenological patterns of nine perennial plants in an intertropical semi-arid Mexican scrub': Enregistrer Citer Cité 121 fois Autres articles Les 8 versions
# Citation text for 'Estimation and evaluation of winter wheat phenology in the central Great Plains': Enregistrer Citer Cité 227 fois Autres articles Les 8 versions
# Citation text for 'Waterlogging and soil freezing during dormancy affected root and shoot phenology and growth of Scots pine saplings': Enregistrer Citer Cité 11 fois Autres articles Les 10 versions
# Citation text for 'Carbohydrate concentrations in honey mesquite roots in relation to phenological development and reproductive condition': Enregistrer Citer Cité 34 fois Autres articles Les 5 versions  Version HTML
# Citation text for 'Optimizing chickpea phenology to available water under current and future climates': Enregistrer Citer Cité 68 fois Autres articles Les 7 versions
# Citation text for 'Cordaixylon dumusum (Cordaitales). II. Reproductive biology, phenology, and growth ecology': Enregistrer Citer Cité 38 fois Autres articles Les 8 versions
# Citation text for 'Growth establishment and phenology of four woody S aharan species': Enregistrer Citer Cité 11 fois Autres articles Les 6 versions
# Citation text for 'Responses of phenology and biomass production of boreal fens to climate warming under different water‐table level regimes': Enregistrer Citer Cité 103 fois Autres articles Les 15 versions
# Citation text for 'Water stress and phenology in wheat': Enregistrer Citer Cité 216 fois Autres articles Les 6 versions
# Citation text for 'The dynamics of potassium uptake and use, leaf gas exchange and root growth throughout plant phenological development and its effects on seed yield in wheat …': Enregistrer Citer Cité 40 fois Autres articles Les 13 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=210
# Citation text for 'Relation between oak tree phenology and the secretion of organic matter degrading enzymes by Lactarius quietus ectomycorrhizas before and during bud break': Enregistrer Citer Cité 147 fois Autres articles Les 12 versions
# Citation text for 'Carbon balance in grapevines (Vitis vinifera L.): effect of environment, cultivar and phenology on carbon gain, losses and allocation': Enregistrer Citer Cité 7 fois Autres articles Les 11 versions
# Citation text for 'Seasonal phenology of woolly apple aphid (Hemiptera: Aphididae) in Central Washington': Enregistrer Citer Cité 53 fois Autres articles Les 11 versions
# Citation text for 'Banana phenology in relation to phytophagous nematodes.': Enregistrer Citer Cité 15 fois Autres articles Les 2 versions
# Citation text for 'Impacts of bud set and lammas phenology on root: shoot biomass partitioning and carbon gain physiology in poplar': Enregistrer Citer Cité 9 fois Autres articles Les 9 versions
# Citation text for 'Genetic yield gain between 1942 and 2013 and associated changes in phenology, yield components and root traits of Australian barley': Enregistrer Citer Cité 8 fois Autres articles Les 8 versions
# Citation text for 'Influence of photoperiod on shoot and root frost tolerance and bud phenology of white spruce seedlings (Piceaglauca)': Enregistrer Citer Cité 102 fois Autres articles Les 5 versions
# Citation text for 'Glucosinolate profile and distribution among plant tissues and phenological stages of field-grown horseradish': Enregistrer Citer Cité 66 fois Autres articles Les 9 versions
# Citation text for 'Influence of physiological phenology on the seasonal pattern of ecosystem respiration in deciduous forests': Enregistrer Citer Cité 68 fois Autres articles Les 18 versions
# Citation text for 'Plant population and row spacing effects on corn: Plant growth, phenology, and grain yield': Enregistrer Citer Cité 65 fois Autres articles Les 6 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=220
# Citation text for 'Growth and phenology of Dittrichia graveolens, a rapidly spreading invasive plant in California': Enregistrer Citer Cité 12 fois Autres articles Les 7 versions
# Citation text for 'Effect of environmental and phenological factors on the antimicrobial activity of Cochlospermum regium (Schrank) Pilg. roots': Enregistrer Citer Cité 19 fois Autres articles Les 19 versions  En cache
# Citation text for 'Phenology, morphology, aboveground biomass and root-associated soil respiration of Arabidopsis thaliana down-regulated cell wall mutants of MYB75, KNAT7, and …': Enregistrer Citer Cité 12 fois Autres articles Les 4 versions
# Citation text for 'Soil and stem water storage determine phenology and distribution of tropical dry forest trees': Enregistrer Citer Cité 1114 fois Autres articles Les 13 versions
# Citation text for 'Phytophthora root rot and irrigation schedule influence growth and phenology of processing tomatoes.': Enregistrer Citer Cité 15 fois Autres articles Les 4 versions
# Citation text for 'Effects of soil properties, nitrogen application, plant phenology, and their interactions on plant uptake of cadmium in wheat': Enregistrer Citer Cité 49 fois Autres articles Les 7 versions
# Citation text for 'Diurnal and seasonal variability of soil CO2 efflux in a cropland ecosystem on the Tibetan Plateau': Enregistrer Citer Cité 145 fois Autres articles Les 11 versions
# Citation text for 'Plant phenology changes and drivers on the Qinghai–Tibetan Plateau': Enregistrer Citer Cité 215 fois Autres articles Les 5 versions
# Citation text for 'Distribution of non-structural nitrogen and carbohydrate compounds in mature oak trees in a temperate forest at four key phenological stages': Enregistrer Citer Cité 106 fois Autres articles Les 14 versions
# Citation text for 'Effects of drought and salinity on maize phenology, morphology and productivity in a semi-arid environment': Enregistrer Citer Cité 13 fois Autres articles Les 6 versions  Version HTML
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=230
# Citation text for 'Phenological and Phytochemical Changes Correlate with Differential Interactions of Verticillium dahliae with Broccoli and Cauliflower': Enregistrer Citer Cité 49 fois Autres articles Les 12 versions
# Citation text for 'Quantitative effects of soil nitrate, growth potential and phenology on symbiotic nitrogen fixation of pea (Pisum sativum L.)': Enregistrer Citer Cité 217 fois Autres articles Les 15 versions
# Citation text for 'A Simulation Model for Grassland Primary Producer Phenology and Biomass Dynamic': Enregistrer Citer Cité 31 fois Autres articles Les 2 versions
# Citation text for 'Rhizogenesis and concentration of carbohydrates in cuttings harvested at different phenological stages of once-blooming rose shrubs and treated with rooting …': Enregistrer Citer Cité 14 fois Autres articles Les 4 versions
# Citation text for 'Reverse phenology and dry‐season water uptake by Faidherbia albida (Del.) A. Chev. in an agroforestry parkland of Sudanese west Africa': Enregistrer Citer Cité 204 fois Autres articles Les 13 versions
# Citation text for 'The mechanisms of phenology: the patterns and processes of phenological shifts': Enregistrer Citer Cité 263 fois Autres articles Les 9 versions
# Citation text for 'Phenology, root growth and root carbohydrates of Lehmann lovegrass (Eragrostis lehmanniana) in response to grazing': Enregistrer Citer Cité 4 fois Autres articles Les 2 versions  Version HTML
# Citation text for 'Phenology, Nitrogen Status, and Yield of Red Clover (Trifolium pretense L.) Affected by Application of Vitamin B12, Humic Acid, and Enriched Biochar': Enregistrer Citer Cité 3 fois Autres articles Les 5 versions  En cache
# Citation text for 'Relationship of plant phenology to corn yield loss resulting from western corn rootworm (Coleoptera: Chrysomelidae) larval injury, nitrogen deficiency, and high plant …': Enregistrer Citer Cité 61 fois Autres articles Les 5 versions
# Citation text for 'Effect of grafting on phenology, susceptibility to Phytophthora cinnamomi and hormone profile of chestnut': Enregistrer Citer Cité 6 fois Autres articles Les 6 versions
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=240
# Citation text for 'Ethnopharmacology and phenology of high-altitude medicinal plants in Kashmir, Northern Himalaya': Enregistrer Citer Cité 37 fois Autres articles Les 5 versions  Version HTML
# Citation text for 'Comparison of two coniferous plantations in central Japan with respect to forest productivity, growth phenology and soil nitrogen dynamics': Enregistrer Citer Cité 40 fois Autres articles Les 9 versions
# Citation text for 'Leaf phenology rather than mycorrhizal type regulates soil nematode abundance, but collectively affects nematode diversity in seven common subtropical tree …': Enregistrer Citer Cité 8 fois Autres articles Les 6 versions
# Citation text for 'Phenology, photosynthesis, and phosphorus in European beech (Fagus sylvatica L.) in two forest soils with contrasting P contents': Enregistrer Citer Cité 58 fois Autres articles Les 7 versions
# Citation text for 'Autumn, the neglected season in climate change research': Enregistrer Citer Cité 542 fois Autres articles Les 10 versions
# Citation text for 'Quinoa-morphology, phenology and prospects for its production as a new crop in Europe': Enregistrer Citer Cité 257 fois Autres articles Les 5 versions
# Citation text for 'The dark side of animal phenology': Enregistrer Citer Cité 41 fois Autres articles Les 10 versions
# Citation text for 'Leaf bacterial microbiota response to flooding is controlled by plant phenology in wheat (Triticum aestivum L.)': Enregistrer Citer Cité 15 fois Autres articles Les 12 versions
# Citation text for 'Effects of climate warming and prolonged snow cover on phenology of the early life history stages of four alpine herbs on the southeastern Tibetan Plateau': Enregistrer Citer Cité 38 fois Autres articles Les 8 versions
# Citation text for 'Variability of phenology and fluxes of water and carbon with observed and simulated soil moisture in the Ent Terrestrial Biosphere Model (Ent TBM version 1.0. 1.0. 0)': Enregistrer Citer Cité 48 fois Autres articles Les 14 versions  Version HTML
# Fetching: https://scholar.google.com/scholar?q=roots%20AND%20phenology&start=250
# Citation text for 'Phenology and resource use in three co-occurring grassland annuals': Enregistrer Citer Cité 106 fois Autres articles Les 9 versions
# ...
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=30
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=30
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D30&q=EgSdiEk6GMuEl74GIixl5NmpCmUuUPMzzm6g8-rqZJkwvU1s-l0BYaP6iGnOZW2Bz2FjrDrpfEBU9zIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=40
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=40
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D40&q=EgSdiEk6GMyEl74GIiyIea3Ft3kBD9jzadg8g_a6BtQ69lsfgxFi6FPr4Rr2J96R5gJW8NgINxBqTTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=50
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=50
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D50&q=EgSdiEk6GMyEl74GIixmXfdifl07Jzm1i9icfHTB-m5VniWX9FzkzX0GWRWHjW7i4KfBZ4H2LxXQETIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=60
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=60
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D60&q=EgSdiEk6GMyEl74GIiyy-fSRPbUBZlGEHFDvr7biE8wAO6VPZjkAMWRcJZyXpcfrnH3YBIv_Bs_CyDIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=70
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=70
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D70&q=EgSdiEk6GM2El74GIiywJwR7gSzdEABXRpIrTkJ3IB1wJigH2ObVY3VaoOMdaJOdOt-iNiDiNu_idjIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=80
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=80
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D80&q=EgSdiEk6GM2El74GIixWDBY4JLMQ7yMUaoMSQhIUFhdR6sMbB3e1jYpka8HICMbcMMrAyWZWIQ0oNzIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=90
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=90
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D90&q=EgSdiEk6GM6El74GIiyjGwh2WbbNIVWiXtxhQIHSQHhn53eV6uG_vASEivxEgy8UkcWpCx-MVswRVTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=100
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=100
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D100&q=EgSdiEk6GM6El74GIizw-rThtdFiv5lg4-T6jGwTIwGIYyWaI1Db2bOiVdQgNjbn3Pt8TpA4RFP_tzIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=110
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=110
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D110&q=EgSdiEk6GM-El74GIiyfzF-RCXO3UfJVN6bfMld7v36ArrMWEkXq43Dyro6pGNkRsSMSGf_qQi_UxDIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=120
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=120
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D120&q=EgSdiEk6GM-El74GIizjK3ggAELks0Acxyey1nqoOaEp-8bcGOHN6b0DHdD3INsa_8xxh2pYMHIxrzIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=130
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=130
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D130&q=EgSdiEk6GM-El74GIiwDySw_qJSnbif9dsJKpPAa2WSb0jRWBNsK5itub_npEu-MO4pQeAmDSKmf-DIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=140
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=140
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D140&q=EgSdiEk6GNCEl74GIixlWr3cDTnmb_0ENPvk5oDk059z9KSfYqhG-lUI0FNlkYIofqfGccruPqyjPTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=150
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=150
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D150&q=EgSdiEk6GNCEl74GIiw0xZRJhIjcWnprfQuISF79Bdf40gHnu32RdGAHW4h7A7-t8yiqResfjYyDhzIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=160
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=160
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D160&q=EgSdiEk6GNGEl74GIizS0O4Fwl5mnvjHGgDhYwVIbxVwD6r_dIexBz1F721bJzr1mBz5Pwfm0zyb5zIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=170
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=170
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D170&q=EgSdiEk6GNGEl74GIiyp8dHTqcqaDwrIjjTN7hLOcTDHRbYlOkfKFE9CU4FDtp6Ks5rjmexPQtJwNTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=180
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=180
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D180&q=EgSdiEk6GNKEl74GIizY91dfbON9lsla5VGUgMU92vz8awfPnM4MsX5Bhd3Adr5DZHD8HUl90zOJeDIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=190
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=190
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D190&q=EgSdiEk6GNKEl74GIixH1GVETIIac6zuVOe7nUNlb6uMk92sOTBQ-AL2FFxhmObHN2ymQ7gvgMVjNTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=200
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=200
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D200&q=EgSdiEk6GNOEl74GIizcAQp3jRm-gAMrAJz8MZ-zL9an_Ri5YFJzUUCCDLq2QxsKzyMY2BQt89t_VzIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=210
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=210
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D210&q=EgSdiEk6GNOEl74GIiyPnT8YNVoU-meVstWnRZYh_wF3WTStFbtLBlEKjMHUKDpFY4TjcsuxgrIX1jIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=220
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=220
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D220&q=EgSdiEk6GNSEl74GIizO7bLj51316JfmyVVaFrRLkQOgZMrMRcvdwG63XjRYBqhjZWJrA5_YffxcZTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=230
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=230
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D230&q=EgSdiEk6GNSEl74GIixWz9W0FcBIWv_R_BideA2nVZGgAyJOUgadJ36Lodi35uWAc32hLc0OKo4shDIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=240
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=240
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D240&q=EgSdiEk6GNSEl74GIiyuY3oW0V5sV6RtKu7_k0B2IORVGifh04W6UQsOiRsrNZkNEyVUj06Vmi8cuDIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=250
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=250
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D250&q=EgSdiEk6GNWEl74GIixKw3PXF6T8CMtongl767nSLurMOQKjEdmrhznr3jcueqeNi0jKzctofEvFsTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=260
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=260
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D260&q=EgSdiEk6GNWEl74GIiwxzRghloe6TFuq4-b44MhsDOV1XXBBMiTX7JbGglAV2SD_75hz2IYiZV7wwTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=270
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=270
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D270&q=EgSdiEk6GNaEl74GIiyvnH2Ee-mIEQss8jO4FpQtcNm3tbjRu6jAxIE2YdPrYP62alEWTtYYyaeYqTIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=280
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=280
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D280&q=EgSdiEk6GNaEl74GIiwnq3ufs9UNnBCY2AYG7paAcTbDyXmNm_2oK-GqoKfjD2IaBulHvBsyCM1HOzIBcloBQw
# Fetching: https://scholar.google.com/scholar?q=%22roots%20production%22&start=290
# Failed to fetch page: https://scholar.google.com/scholar?q=%22roots%20production%22&start=290
# 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://scholar.google.com/scholar%3Fq%3D%2522roots%2520production%2522%26start%3D290&q=EgSdiEk6GNaEl74GIixzjTK987gnlh-GpMOEmYWg3ZX8K-pdEtDSJogTbiaw1B5mXH6RtULEWbzFDDIBcloBQw
#                                                  Title  \
# 0    Plant phenology: a critical controller of soil...
# 1    The mycorrhizal status, root anatomy, and phen...
# 2    Root phenology unresponsive to earlier snowmel...
# 3    Soybean root development relative to vegetativ...
# 4    Root phenology in an Arctic shrub-graminoid co...
# ..                                                 ...
# 491  Phenological traits, litterfall production, an...
# 492  Leaf Tissue C: N is Modified by Growing Season...
# 493                    Seasonally dry tropical forests
# 494  Soil fungal community of wheat Triticum aestiv...
# 495  Comparison of ingrowth core and sequential soi...
#
#                                                   Link  \
# 0    https://academic.oup.com/jxb/article-abstract/...
# 1    https://cdnsciencepub.com/doi/abs/10.1139/b88-166
# 2    https://besjournals.onlinelibrary.wiley.com/do...
# 3    https://acsess.onlinelibrary.wiley.com/doi/abs...
# 4    https://link.springer.com/article/10.1186/s406...
# ..                                                 ...
# 491  https://www.researchsquare.com/article/rs-9733...
# 492  https://digitalcommons.usu.edu/researchweek/Re...
# 493  https://books.google.com/books?hl=fr&lr=&id=aa...
# 494  https://www.sciencedirect.com/science/article/...
# 495  https://onlinelibrary.wiley.com/doi/abs/10.111...
#
#                                               Abstract  \
# 0    … of phenology that increases total transpirat...
# 1    … of this species followed root phenology clos...
# 2    … We expected earlier snowmelt to advance both...
# 3    … root phenology and soybean vegetative (Vn) a...
# 4    … In 2013 and 2014, we measured root phenology...
# ..                                                 ...
# 491  … In the present study, mean belowground bioma...
# 492  … Early season grazing heavily reduced above-a...
# 493  … of plant life forms in terms of structure, p...
# 494  … (p < 0.05) between phenological statuses in ...
# 495  … , we argue that ignoring root phenology woul...
#
#                                                Authors  \
# 0                                    EA Nord, JP Lynch
# 1                             MC Brundrett, B Kendrick
# 2                   G Blume‐Werry, R Jansson, A Milbau
# 3                 JA Torrion, TD Setiyono, KG Cassman…
# 4                    L Radville, E Post, DM Eissenstat
# ..                                                 ...
# 491  M Kamruzzaman, SK Paul - 2020 - researchsquare...
# 492  R Choi, K Beard, J Leffler, J Welker, J Schutz...
# 493  SH Bullock, HA Mooney, E Medina - 1995 - books...
# 494         M Levi, I Applebaum, C Sherman, T Doniger…
# 495                 S Chen, S Lin, T Reinsch, R Loges…
#
#                             Journal    Year  Citations  \
# 0    Journal of experimental botany  2009.0        350
# 1        Canadian Journal of Botany  1988.0        312
# 2                Functional Ecology  2017.0         32
# 3                        Agronomy …  2012.0         42
# 4          Climate Change Responses  2016.0         31
# ..                              ...     ...        ...
# 491                                     NaN          0
# 492                                     NaN          0
# 493                                     NaN        614
# 494                     Rhizosphere  2022.0          7
# 495              Grass and Forage …  2016.0         31
#
#                     SearchTerm
# 0          roots AND phenology
# 1          roots AND phenology
# 2          roots AND phenology
# 3          roots AND phenology
# 4          roots AND phenology
# ..                         ...
# 491  belowground AND phenology
# 492  belowground AND phenology
# 493  belowground AND phenology
# 494  belowground AND phenology
# 495  belowground AND phenology
#
# [426 rows x 8 columns]

# %%
import pandas as pd
from pymed import PubMed
import time

# Configuración de palabras clave y rango de años
keywords = ["roots AND phenology", "fine roots AND growth"]
start_year = 1990
end_year = 2025
max_results = 50  # Número máximo de resultados

# Función para buscar en PubMed
def search_pubmed(keywords, start_year, end_year, max_results=50):
    pubmed = PubMed(tool="PubMedSearcher", email="tu@email.com")  # Reemplaza con tu email
    query = ' AND '.join(keywords)
    results = pubmed.query(query, max_results=max_results)
    papers = []

    for result in results:
        # Obtiene la fecha de publicación
        pub_date = result.publication_date
        if pub_date:
            # Extrae el año de la fecha de publicación
            pub_year = int(pub_date[:4]) if isinstance(pub_date, str) else pub_date.year
        else:
            pub_year = None

        # Filtra por año de publicación
        if pub_year and start_year <= pub_year <= end_year:
            paper = {
                'title': result.title,
                'abstract': result.abstract if result.abstract else "Resumen no disponible",
                'keywords': ', '.join(result.keywords) if result.keywords else ', '.join(keywords),
                'authors': ', '.join([author['lastname'] + ' ' + author['initials'] for author in result.authors]) if result.authors else "Autores no disponibles",
                'journal': result.journal if result.journal else "Revista no disponible",
                'date': pub_year,
                'source': 'PubMed'
            }
            papers.append(paper)
            print(f"Publicación encontrada: {result.title}")  # Imprime cada publicación

    return papers

# Realizar búsqueda en PubMed
try:
    pubmed_papers = search_pubmed(keywords, start_year, end_year, max_results)
except Exception as e:
    print(f"Error durante la búsqueda: {e}")
    pubmed_papers = []

# Mostrar resultados
if pubmed_papers:
    df = pd.DataFrame(pubmed_papers)
    print(df)

    # Guardar la tabla en un archivo CSV
    df.to_csv('pubmed_papers.csv', index=False)
else:
    print("No se encontraron resultados o hubo un error en la búsqueda.")
# Out:
# Publicación encontrada: Above- and belowground phenology responses of subtropical Chinese fir (Cunninghamia lanceolata) to soil warming, precipitation exclusion and their interaction.
# Publicación encontrada: Effects of warming on fine root lifespan of forests: A review.
# Publicación encontrada: Divergent seasonal responses of above- and below-ground to environmental factors in alpine grassland.
# Publicación encontrada: Effects of Soil Water Shortage on Seedling Shoot and Root Growth of Saragolle Lucana Tetraploid Wheat (
# Publicación encontrada: Above- and belowground interplay: Canopy CO
# Publicación encontrada: Separating the effects of air and soil temperature on silver birch. Part I. Does soil temperature or resource competition determine the timing of root growth?
# Publicación encontrada: Eco-archaeological excavation techniques reveal snapshots of subterranean truffle growth.
# Publicación encontrada: Responses of root phenology in ecotypes of Eriophorum vaginatum to transplantation and warming in the Arctic.
# Publicación encontrada: Pulse Root Ideotype for Water Stress in Temperate Cropping System.
# Publicación encontrada: Remarkable Similarity in Timing of Absorptive Fine-Root Production Across 11 Diverse Temperate Tree Species in a Common Garden.
# Publicación encontrada: Dynamics of above- and belowground responses of silver birch saplings and soil gases to soil freezing and waterlogging during dormancy.
# Publicación encontrada: Prevalence and phenology of fine root endophyte colonization across populations of Lycopodiella inundata.
# Publicación encontrada: Climatic and physiological regulation of the bimodal xylem formation pattern in Pinus pinaster saplings.
# Publicación encontrada: Dwelling in the deep - strongly increased root growth and rooting depth enhance plant interactions with thawing permafrost soil.
# Publicación encontrada: Rapid temporal changes in root colonization by arbuscular mycorrhizal fungi and fine root endophytes, not dark septate endophytes, track plant activity and environment in an alpine ecosystem.
# Publicación encontrada: To spend or to save? Assessing energetic growth-storage tradeoffs in native and invasive woody plants.
# Publicación encontrada: Stand development and other intrinsic factors largely control fine-root dynamics with only subtle modifications from resource availability.
# Publicación encontrada: Phloem Girdling of Norway Spruce Alters Quantity and Quality of Wood Formation in Roots Particularly Under Drought.
# Publicación encontrada: Prolonged Soil Frost Affects Hydraulics and Phenology of Apple Trees.
# Publicación encontrada: Summer dormancy, drought survival and functional resource acquisition strategies in California perennial grasses.
# Publicación encontrada: Carbon Allocation into Different Fine-Root Classes of Young Abies alba Trees Is Affected More by Phenology than by Simulated Browsing.
# Publicación encontrada: Impact of treated wastewater on growth, respiration and hydraulic conductivity of citrus root systems in light and heavy soils.
# Publicación encontrada: Changes in fine-root production, phenology and spatial distribution in response to N application in irrigated sweet cherry trees.
# Publicación encontrada: The hidden season: growing season is 50% longer below than above ground along an arctic elevation gradient.
# Publicación encontrada: Seasonal changes in carbon and nitrogen compound concentrations in a Quercus petraea chronosequence.
# Publicación encontrada: Links between belowground and aboveground resource-related traits reveal species growth strategies that promote invasive advantages.
# Publicación encontrada: Intra-annual nutrient flux in Pinus taeda.
# Publicación encontrada: Dynamics of phreatophyte root growth relative to a seasonally fluctuating water table in a Mediterranean-type environment.
# Publicación encontrada: Elevated CO2 and O3 effects on fine-root survivorship in ponderosa pine mesocosms.
# Publicación encontrada: Dry-season leaf flushing of Enterolobium cyclocarpum (ear-pod tree): above- and below-ground phenology and water relations.
# Publicación encontrada: Genetic and environmental control of seasonal carbohydrate dynamics in trees of diverse Pinus sylvestris populations.
# Publicación encontrada: Below-ground carbon input to soil is controlled by nutrient availability and fine root dynamics in loblolly pine.
# Publicación encontrada: Water stress responses of seedlings of four Mediterranean oak species.
# Publicación encontrada: The influence of below ground herbivory and plant competition on growth and biomass allocation of purple loosestrife.
# Publicación encontrada: Seasonal branch and fine root growth of juvenile loblolly pine five growing seasons after fertilization.
# Publicación encontrada: Root proliferation characteristics of seven perennial arid-land grasses in nutrient-enriched microsites.
#                                                 title  \
# 0   Above- and belowground phenology responses of ...
# 1   Effects of warming on fine root lifespan of fo...
# 2   Divergent seasonal responses of above- and bel...
# 3   Effects of Soil Water Shortage on Seedling Sho...
# 4         Above- and belowground interplay: Canopy CO
# 5   Separating the effects of air and soil tempera...
# 6   Eco-archaeological excavation techniques revea...
# 7   Responses of root phenology in ecotypes of Eri...
# 8   Pulse Root Ideotype for Water Stress in Temper...
# 9   Remarkable Similarity in Timing of Absorptive ...
# 10  Dynamics of above- and belowground responses o...
# 11  Prevalence and phenology of fine root endophyt...
# 12  Climatic and physiological regulation of the b...
# 13  Dwelling in the deep - strongly increased root...
# 14  Rapid temporal changes in root colonization by...
# 15  To spend or to save? Assessing energetic growt...
# 16  Stand development and other intrinsic factors ...
# 17  Phloem Girdling of Norway Spruce Alters Quanti...
# 18  Prolonged Soil Frost Affects Hydraulics and Ph...
# 19  Summer dormancy, drought survival and function...
# 20  Carbon Allocation into Different Fine-Root Cla...
# 21  Impact of treated wastewater on growth, respir...
# 22  Changes in fine-root production, phenology and...
# 23  The hidden season: growing season is 50% longe...
# 24  Seasonal changes in carbon and nitrogen compou...
# 25  Links between belowground and aboveground reso...
# 26         Intra-annual nutrient flux in Pinus taeda.
# 27  Dynamics of phreatophyte root growth relative ...
# 28  Elevated CO2 and O3 effects on fine-root survi...
# 29  Dry-season leaf flushing of Enterolobium cyclo...
# 30  Genetic and environmental control of seasonal ...
# 31  Below-ground carbon input to soil is controlle...
# 32  Water stress responses of seedlings of four Me...
# 33  The influence of below ground herbivory and pl...
# 34  Seasonal branch and fine root growth of juveni...
# 35  Root proliferation characteristics of seven pe...
#
#                                              abstract  \
# 0   Plant phenology plays an important role in nut...
# 1   As an important parameter of forests growth, f...
# 2   Under current global warming, the relationship...
# 3   Ancient wheats may be a source of traits that ...
# 4   In forests, mycorrhizal fungi regulate carbon ...
# 5   The aboveground parts of boreal forest trees m...
# 6   Despite its status as a highly-prized and cove...
# 7   The effect of climate change on phenology and ...
# 8   Pulses are a key component of crop production ...
# 9   Long-term minirhizotron observations of absorp...
# 10  Winter precipitation and soil freeze-thaw even...
# 11  Mycorrhizal fungi are critical components of t...
# 12  Seasonality in tree cambial activity and xylem...
# 13  Climate-warming-induced permafrost thaw expose...
# 14  Fungal root endophytes play an important role ...
# 15  Many non-native woody plants invade low-light ...
# 16  Forest productivity depends on resource acquis...
# 17  Carbon (C) availability plays an essential rol...
# 18  Restoration of an adequate water supply in spr...
# 19  Evidence suggests drought severity is increasi...
# 20  Abies alba (European silver fir) was used to i...
# 21  Roots interact with soil properties and irriga...
# 22  Factors regulating fine-root growth are poorly...
# 23  There is compelling evidence from experiments ...
# 24  Forest productivity declines with tree age. Th...
# 25  Belowground processes are rarely considered in...
# 26  Intra-annual nutrient (nitrogen, phosphorus, p...
# 27  While seasonal redistribution of fine root bio...
# 28  Atmospheric carbon dioxide (CO(2)) and ozone (...
# 29  Above- and belowground phenology and water rel...
# 30  We explored environmental and genetic factors ...
# 31  •  Availability of growth limiting resources m...
# 32  Effects of water stress on phenology, growth, ...
# 33  Experiments investigating plant-herbivore inte...
# 34  In 1989, we established two replications of tw...
# 35  We compared root proliferation in fertilized m...
#
#                                              keywords  \
# 0   Aboveground phenology, Climate change, Fine ro...
# 1   carbon allocation, fine root lifespan, impact ...
# 2   above-ground, alpine steppe, below-ground, sea...
# 3   ancient wheats, durum wheat, rhizosheath, root...
# 4   Fagus sylvatica, Mediterranean forest, mycorrh...
# 5   boreal tree species, fine root dynamics, growt...
# 6   Archaeological excavation, Fruitbody formation...
# 7   Arctic tundra, Ecotypes, Fine roots, Root phen...
# 8   avoidance, constraints, dicotyledon, dryland c...
# 9   absorptive fine roots, deciduous, evergreen, p...
# 10  abiotic stress, climate change, greenhouse gas...
# 11  FRE, Glomeromycotina, Heathland ecology, Marsh...
# 12  C stocks, C uptake, drought, water relations, ...
# 13  Eriophorum, arctic tundra, fine roots, minirhi...
# 14  Arbuscular mycorrhizal fungi, Dark septate end...
# 15  Carbon allocation, Invasions, Nonstructural ca...
# 16         roots AND phenology, fine roots AND growth
# 17  Norway spruce, carbon allocation, drought, gir...
# 18  fine roots, native embolism, refilling, starch...
# 19  California grasslands, Poaceae, dehydration av...
# 20         roots AND phenology, fine roots AND growth
# 21  irrigation, membrane leakage, minirhizotron, o...
# 22  N fertilization, central Chile, fine-root dyna...
# 23  below ground, below-ground, belowground, fine ...
# 24  ageing, non-structural carbohydrates, non-stru...
# 25         roots AND phenology, fine roots AND growth
# 26         roots AND phenology, fine roots AND growth
# 27         roots AND phenology, fine roots AND growth
# 28         roots AND phenology, fine roots AND growth
# 29         roots AND phenology, fine roots AND growth
# 30         roots AND phenology, fine roots AND growth
# 31  fine root turnover, loblolly pine, minirhizotr...
# 32         roots AND phenology, fine roots AND growth
# 33  Biological control, Biomass allocation, Key wo...
# 34         roots AND phenology, fine roots AND growth
# 35  Agropyron, Fertilized microsites, Psathyrostac...
#
#                                               authors  \
# 0   Qu Z, Lin C, Zhao H, Chen T, Yao X, Wang X, Ya...
# 1                   Liu YH, DU XL, Huang JX, Xiong DC
# 2                 Qin X, Nie X, Wang X, Hong J, Yan Y
# 3   Bochicchio R, Labella R, Rossi R, Perniola M, ...
# 4   Scartazza A, Sbrana C, D'Andrea E, Matteucci G...
# 5   Kilpeläinen J, Domisch T, Lehto T, Piirainen S...
# 6   Büntgen U, Peter M, Tegel W, Stobbe U, Elburg ...
# 7   Ma T, Parker T, Unger S, Gewirtzman J, Fetcher...
# 8   Rao S, Armstrong R, Silva-Perez V, Tefera AT, ...
# 9   Withington JM, Goebel M, Bułaj B, Oleksyn J, R...
# 10  Repo T, Domisch T, Roitto M, Kilpeläinen J, Wa...
# 11         Kowal J, Arrigoni E, Serra J, Bidartondo M
# 12  Garcia-Forner N, Vieira J, Nabais C, Carvalho ...
# 13  Blume-Werry G, Milbau A, Teuber LM, Johansson ...
# 14  Bueno de Mesquita CP, Martinez Del Río CM, Sud...
# 15                              Hinman ED, Fridley JD
# 16                              Coleman MD, Aubrey DP
# 17                      Rainer-Lethaus G, Oberhuber W
# 18                   Beikircher B, Mittmann C, Mayr S
# 19            Balachowski JA, Bristiel PM, Volaire FA
# 20                  Endrulat T, Buchmann N, Brunner I
# 21  Paudel I, Cohen S, Shaviv A, Bar-Tal A, Bernst...
# 22                             Artacho P, Bonomelli C
# 23     Blume-Werry G, Wilson SD, Kreyling J, Milbau A
# 24  Gilson A, Barthes L, Delpierre N, Dufrêne É, F...
# 25         Smith MS, Fridley JD, Goebel M, Bauerle TL
# 26  Albaugh TJ, Allen HL, Stape JL, Fox TR, Rubila...
# 27           Canham CA, Froend RH, Stock WD, Davies M
# 28       Phillips DL, Johnson MG, Tingey DT, Storm MJ
# 29    Rojas-Jiménez K, Holbrook NM, Gutiérrez-Soto MV
# 30  Oleksyn J, Zytkowiak R, Karolewski P, Reich PB...
# 31  King JS, Albaugh TJ, Allen HL, Buford M, Strai...
# 32         Fotelli MN, Radoglou KM, Constantinidou HI
# 33                     Nötzold R, Blossey B, Newton E
# 34     Sword MA, Gravatt DA, Faulkner PL, Chambers JL
# 35                        Larigauderie A, Richards JH
#
#                                               journal  date  source
# 0                The Science of the total environment  2024  PubMed
# 1   Ying yong sheng tai xue bao = The journal of a...  2023  PubMed
# 2                          Frontiers in plant science  2023  PubMed
# 3                         Plants (Basel, Switzerland)  2022  PubMed
# 4                           Plant, cell & environment  2022  PubMed
# 5                                     Tree physiology  2022  PubMed
# 6                                      Fungal biology  2021  PubMed
# 7                The Science of the total environment  2021  PubMed
# 8                         Plants (Basel, Switzerland)  2021  PubMed
# 9                          Frontiers in plant science  2021  PubMed
# 10                                    Tree physiology  2021  PubMed
# 11                                         Mycorrhiza  2020  PubMed
# 12                                    Tree physiology  2019  PubMed
# 13                                The New phytologist  2019  PubMed
# 14                                         Mycorrhiza  2018  PubMed
# 15                                          Oecologia  2018  PubMed
# 16                                    Tree physiology  2018  PubMed
# 17                         Frontiers in plant science  2018  PubMed
# 18                         Frontiers in plant science  2016  PubMed
# 19                                   Annals of botany  2016  PubMed
# 20                                           PloS one  2016  PubMed
# 21                                    Tree physiology  2016  PubMed
# 22                                    Tree physiology  2016  PubMed
# 23                                The New phytologist  2015  PubMed
# 24                                    Tree physiology  2014  PubMed
# 25                                           PloS one  2014  PubMed
# 26                                    Tree physiology  2012  PubMed
# 27                                          Oecologia  2012  PubMed
# 28                                          Oecologia  2009  PubMed
# 29                                    Tree physiology  2007  PubMed
# 30                                    Tree physiology  2003  PubMed
# 31                                The New phytologist  2002  PubMed
# 32                                    Tree physiology  2001  PubMed
# 33                                          Oecologia  1997  PubMed
# 34                                    Tree physiology  1996  PubMed
# 35                                          Oecologia  1994  PubMed

# %%
import pandas as pd
from pymed import PubMed
import time

# Configuración de palabras clave y rango de años
keywords = ["roots AND phenology", "fine roots AND growth"]
start_year = 1990
end_year = 2025
max_results = 50  # Número máximo de resultados

# Función para buscar en PubMed
def search_pubmed(keywords, start_year, end_year, max_results=50):
    pubmed = PubMed(tool="PubMedSearcher", email="tu@email.com")  # Reemplaza con tu email
    query = ' AND '.join(keywords)
    results = pubmed.query(query, max_results=max_results)
    papers = []

    for result in results:
        # Obtiene la fecha de publicación
        pub_date = result.publication_date
        if pub_date:
            # Extrae el año de la fecha de publicación
            pub_year = int(pub_date[:4]) if isinstance(pub_date, str) else pub_date.year
        else:
            pub_year = None

        # Filtra por año de publicación
        if pub_year and start_year <= pub_year <= end_year:
            paper = {
                'Title': result.title,
                'Link': f"https://pubmed.ncbi.nlm.nih.gov/{result.pubmed_id}",  # Enlace al artículo
                'Abstract': result.abstract if result.abstract else "Resumen no disponible",
                'Authors': ', '.join([author['lastname'] + ' ' + author['initials'] for author in result.authors]) if result.authors else "Autores no disponibles",
                'Journal': result.journal if result.journal else "Revista no disponible",
                'Year': pub_year,
                'Citations': '',  # PubMed no proporciona citaciones directamente
                'SearchTerm': query  # Término de búsqueda utilizado
            }
            papers.append(paper)
            print(f"Publicación encontrada: {result.title}")  # Imprime cada publicación

    return papers

# Realizar búsqueda en PubMed
try:
    pubmed_papers = search_pubmed(keywords, start_year, end_year, max_results)
except Exception as e:
    print(f"Error durante la búsqueda: {e}")
    pubmed_papers = []

# Mostrar resultados
if pubmed_papers:
    df = pd.DataFrame(pubmed_papers)
    
    # Reordenar las columnas en el orden solicitado
    df = df[['Title', 'Link', 'Abstract', 'Authors', 'Journal', 'Year', 'Citations', 'SearchTerm']]
    
    print(df)

    # Guardar la tabla en un archivo CSV
    df.to_csv('pubmed_papers2.csv', index=False)
else:
    print("No se encontraron resultados o hubo un error en la búsqueda.")
# Out:
# Publicación encontrada: Above- and belowground phenology responses of subtropical Chinese fir (Cunninghamia lanceolata) to soil warming, precipitation exclusion and their interaction.
# Publicación encontrada: Effects of warming on fine root lifespan of forests: A review.
# Publicación encontrada: Divergent seasonal responses of above- and below-ground to environmental factors in alpine grassland.
# Publicación encontrada: Effects of Soil Water Shortage on Seedling Shoot and Root Growth of Saragolle Lucana Tetraploid Wheat (
# Publicación encontrada: Above- and belowground interplay: Canopy CO
# Publicación encontrada: Separating the effects of air and soil temperature on silver birch. Part I. Does soil temperature or resource competition determine the timing of root growth?
# Publicación encontrada: Eco-archaeological excavation techniques reveal snapshots of subterranean truffle growth.
# Publicación encontrada: Responses of root phenology in ecotypes of Eriophorum vaginatum to transplantation and warming in the Arctic.
# Publicación encontrada: Pulse Root Ideotype for Water Stress in Temperate Cropping System.
# Publicación encontrada: Remarkable Similarity in Timing of Absorptive Fine-Root Production Across 11 Diverse Temperate Tree Species in a Common Garden.
# Publicación encontrada: Dynamics of above- and belowground responses of silver birch saplings and soil gases to soil freezing and waterlogging during dormancy.
# Publicación encontrada: Prevalence and phenology of fine root endophyte colonization across populations of Lycopodiella inundata.
# Publicación encontrada: Climatic and physiological regulation of the bimodal xylem formation pattern in Pinus pinaster saplings.
# Publicación encontrada: Dwelling in the deep - strongly increased root growth and rooting depth enhance plant interactions with thawing permafrost soil.
# Publicación encontrada: Rapid temporal changes in root colonization by arbuscular mycorrhizal fungi and fine root endophytes, not dark septate endophytes, track plant activity and environment in an alpine ecosystem.
# Publicación encontrada: To spend or to save? Assessing energetic growth-storage tradeoffs in native and invasive woody plants.
# Publicación encontrada: Stand development and other intrinsic factors largely control fine-root dynamics with only subtle modifications from resource availability.
# Publicación encontrada: Phloem Girdling of Norway Spruce Alters Quantity and Quality of Wood Formation in Roots Particularly Under Drought.
# Publicación encontrada: Prolonged Soil Frost Affects Hydraulics and Phenology of Apple Trees.
# Publicación encontrada: Summer dormancy, drought survival and functional resource acquisition strategies in California perennial grasses.
# Publicación encontrada: Carbon Allocation into Different Fine-Root Classes of Young Abies alba Trees Is Affected More by Phenology than by Simulated Browsing.
# Publicación encontrada: Impact of treated wastewater on growth, respiration and hydraulic conductivity of citrus root systems in light and heavy soils.
# Publicación encontrada: Changes in fine-root production, phenology and spatial distribution in response to N application in irrigated sweet cherry trees.
# Publicación encontrada: The hidden season: growing season is 50% longer below than above ground along an arctic elevation gradient.
# Publicación encontrada: Seasonal changes in carbon and nitrogen compound concentrations in a Quercus petraea chronosequence.
# Publicación encontrada: Links between belowground and aboveground resource-related traits reveal species growth strategies that promote invasive advantages.
# Publicación encontrada: Intra-annual nutrient flux in Pinus taeda.
# Publicación encontrada: Dynamics of phreatophyte root growth relative to a seasonally fluctuating water table in a Mediterranean-type environment.
# Publicación encontrada: Elevated CO2 and O3 effects on fine-root survivorship in ponderosa pine mesocosms.
# Publicación encontrada: Dry-season leaf flushing of Enterolobium cyclocarpum (ear-pod tree): above- and below-ground phenology and water relations.
# Publicación encontrada: Genetic and environmental control of seasonal carbohydrate dynamics in trees of diverse Pinus sylvestris populations.
# Publicación encontrada: Below-ground carbon input to soil is controlled by nutrient availability and fine root dynamics in loblolly pine.
# Publicación encontrada: Water stress responses of seedlings of four Mediterranean oak species.
# Publicación encontrada: The influence of below ground herbivory and plant competition on growth and biomass allocation of purple loosestrife.
# Publicación encontrada: Seasonal branch and fine root growth of juvenile loblolly pine five growing seasons after fertilization.
# Publicación encontrada: Root proliferation characteristics of seven perennial arid-land grasses in nutrient-enriched microsites.
#                                                 Title  \
# 0   Above- and belowground phenology responses of ...
# 1   Effects of warming on fine root lifespan of fo...
# 2   Divergent seasonal responses of above- and bel...
# 3   Effects of Soil Water Shortage on Seedling Sho...
# 4         Above- and belowground interplay: Canopy CO
# 5   Separating the effects of air and soil tempera...
# 6   Eco-archaeological excavation techniques revea...
# 7   Responses of root phenology in ecotypes of Eri...
# 8   Pulse Root Ideotype for Water Stress in Temper...
# 9   Remarkable Similarity in Timing of Absorptive ...
# 10  Dynamics of above- and belowground responses o...
# 11  Prevalence and phenology of fine root endophyt...
# 12  Climatic and physiological regulation of the b...
# 13  Dwelling in the deep - strongly increased root...
# 14  Rapid temporal changes in root colonization by...
# 15  To spend or to save? Assessing energetic growt...
# 16  Stand development and other intrinsic factors ...
# 17  Phloem Girdling of Norway Spruce Alters Quanti...
# 18  Prolonged Soil Frost Affects Hydraulics and Ph...
# 19  Summer dormancy, drought survival and function...
# 20  Carbon Allocation into Different Fine-Root Cla...
# 21  Impact of treated wastewater on growth, respir...
# 22  Changes in fine-root production, phenology and...
# 23  The hidden season: growing season is 50% longe...
# 24  Seasonal changes in carbon and nitrogen compou...
# 25  Links between belowground and aboveground reso...
# 26         Intra-annual nutrient flux in Pinus taeda.
# 27  Dynamics of phreatophyte root growth relative ...
# 28  Elevated CO2 and O3 effects on fine-root survi...
# 29  Dry-season leaf flushing of Enterolobium cyclo...
# 30  Genetic and environmental control of seasonal ...
# 31  Below-ground carbon input to soil is controlle...
# 32  Water stress responses of seedlings of four Me...
# 33  The influence of below ground herbivory and pl...
# 34  Seasonal branch and fine root growth of juveni...
# 35  Root proliferation characteristics of seven pe...
#
#                                                  Link  \
# 0            https://pubmed.ncbi.nlm.nih.gov/38740199
# 1            https://pubmed.ncbi.nlm.nih.gov/37694432
# 2   https://pubmed.ncbi.nlm.nih.gov/36815013\n2639...
# 3   https://pubmed.ncbi.nlm.nih.gov/36559604\n2925...
# 4            https://pubmed.ncbi.nlm.nih.gov/36541420
# 5   https://pubmed.ncbi.nlm.nih.gov/35939338\n2572...
# 6            https://pubmed.ncbi.nlm.nih.gov/34776232
# 7            https://pubmed.ncbi.nlm.nih.gov/34543789
# 8   https://pubmed.ncbi.nlm.nih.gov/33916833\n2969...
# 9   https://pubmed.ncbi.nlm.nih.gov/33584764\n2572...
# 10  https://pubmed.ncbi.nlm.nih.gov/33440427\n2904...
# 11  https://pubmed.ncbi.nlm.nih.gov/32734329\n9254...
# 12           https://pubmed.ncbi.nlm.nih.gov/31631224
# 13           https://pubmed.ncbi.nlm.nih.gov/31074867
# 14  https://pubmed.ncbi.nlm.nih.gov/30141076\n2297...
# 15  https://pubmed.ncbi.nlm.nih.gov/29882168\n2633...
# 16           https://pubmed.ncbi.nlm.nih.gov/29660101
# 17  https://pubmed.ncbi.nlm.nih.gov/29636766\n2572...
# 18  https://pubmed.ncbi.nlm.nih.gov/27379146\n1246...
# 19  https://pubmed.ncbi.nlm.nih.gov/27325898\n2590...
# 20  https://pubmed.ncbi.nlm.nih.gov/27123860\n1670...
# 21           https://pubmed.ncbi.nlm.nih.gov/27022106
# 22  https://pubmed.ncbi.nlm.nih.gov/26888890\n2572...
# 23           https://pubmed.ncbi.nlm.nih.gov/26390239
# 24           https://pubmed.ncbi.nlm.nih.gov/25122620
# 25  https://pubmed.ncbi.nlm.nih.gov/25105975\n2000...
# 26           https://pubmed.ncbi.nlm.nih.gov/22989738
# 27  https://pubmed.ncbi.nlm.nih.gov/22692384\n1252...
# 28  https://pubmed.ncbi.nlm.nih.gov/19415339\n1126...
# 29           https://pubmed.ncbi.nlm.nih.gov/17669745
# 30           https://pubmed.ncbi.nlm.nih.gov/12651505
# 31           https://pubmed.ncbi.nlm.nih.gov/33873440
# 32           https://pubmed.ncbi.nlm.nih.gov/11269958
# 33           https://pubmed.ncbi.nlm.nih.gov/28307297
# 34           https://pubmed.ncbi.nlm.nih.gov/14871782
# 35  https://pubmed.ncbi.nlm.nih.gov/28313954\n1827...
#
#                                              Abstract  \
# 0   Plant phenology plays an important role in nut...
# 1   As an important parameter of forests growth, f...
# 2   Under current global warming, the relationship...
# 3   Ancient wheats may be a source of traits that ...
# 4   In forests, mycorrhizal fungi regulate carbon ...
# 5   The aboveground parts of boreal forest trees m...
# 6   Despite its status as a highly-prized and cove...
# 7   The effect of climate change on phenology and ...
# 8   Pulses are a key component of crop production ...
# 9   Long-term minirhizotron observations of absorp...
# 10  Winter precipitation and soil freeze-thaw even...
# 11  Mycorrhizal fungi are critical components of t...
# 12  Seasonality in tree cambial activity and xylem...
# 13  Climate-warming-induced permafrost thaw expose...
# 14  Fungal root endophytes play an important role ...
# 15  Many non-native woody plants invade low-light ...
# 16  Forest productivity depends on resource acquis...
# 17  Carbon (C) availability plays an essential rol...
# 18  Restoration of an adequate water supply in spr...
# 19  Evidence suggests drought severity is increasi...
# 20  Abies alba (European silver fir) was used to i...
# 21  Roots interact with soil properties and irriga...
# 22  Factors regulating fine-root growth are poorly...
# 23  There is compelling evidence from experiments ...
# 24  Forest productivity declines with tree age. Th...
# 25  Belowground processes are rarely considered in...
# 26  Intra-annual nutrient (nitrogen, phosphorus, p...
# 27  While seasonal redistribution of fine root bio...
# 28  Atmospheric carbon dioxide (CO(2)) and ozone (...
# 29  Above- and belowground phenology and water rel...
# 30  We explored environmental and genetic factors ...
# 31  •  Availability of growth limiting resources m...
# 32  Effects of water stress on phenology, growth, ...
# 33  Experiments investigating plant-herbivore inte...
# 34  In 1989, we established two replications of tw...
# 35  We compared root proliferation in fertilized m...
#
#                                               Authors  \
# 0   Qu Z, Lin C, Zhao H, Chen T, Yao X, Wang X, Ya...
# 1                   Liu YH, DU XL, Huang JX, Xiong DC
# 2                 Qin X, Nie X, Wang X, Hong J, Yan Y
# 3   Bochicchio R, Labella R, Rossi R, Perniola M, ...
# 4   Scartazza A, Sbrana C, D'Andrea E, Matteucci G...
# 5   Kilpeläinen J, Domisch T, Lehto T, Piirainen S...
# 6   Büntgen U, Peter M, Tegel W, Stobbe U, Elburg ...
# 7   Ma T, Parker T, Unger S, Gewirtzman J, Fetcher...
# 8   Rao S, Armstrong R, Silva-Perez V, Tefera AT, ...
# 9   Withington JM, Goebel M, Bułaj B, Oleksyn J, R...
# 10  Repo T, Domisch T, Roitto M, Kilpeläinen J, Wa...
# 11         Kowal J, Arrigoni E, Serra J, Bidartondo M
# 12  Garcia-Forner N, Vieira J, Nabais C, Carvalho ...
# 13  Blume-Werry G, Milbau A, Teuber LM, Johansson ...
# 14  Bueno de Mesquita CP, Martinez Del Río CM, Sud...
# 15                              Hinman ED, Fridley JD
# 16                              Coleman MD, Aubrey DP
# 17                      Rainer-Lethaus G, Oberhuber W
# 18                   Beikircher B, Mittmann C, Mayr S
# 19            Balachowski JA, Bristiel PM, Volaire FA
# 20                  Endrulat T, Buchmann N, Brunner I
# 21  Paudel I, Cohen S, Shaviv A, Bar-Tal A, Bernst...
# 22                             Artacho P, Bonomelli C
# 23     Blume-Werry G, Wilson SD, Kreyling J, Milbau A
# 24  Gilson A, Barthes L, Delpierre N, Dufrêne É, F...
# 25         Smith MS, Fridley JD, Goebel M, Bauerle TL
# 26  Albaugh TJ, Allen HL, Stape JL, Fox TR, Rubila...
# 27           Canham CA, Froend RH, Stock WD, Davies M
# 28       Phillips DL, Johnson MG, Tingey DT, Storm MJ
# 29    Rojas-Jiménez K, Holbrook NM, Gutiérrez-Soto MV
# 30  Oleksyn J, Zytkowiak R, Karolewski P, Reich PB...
# 31  King JS, Albaugh TJ, Allen HL, Buford M, Strai...
# 32         Fotelli MN, Radoglou KM, Constantinidou HI
# 33                     Nötzold R, Blossey B, Newton E
# 34     Sword MA, Gravatt DA, Faulkner PL, Chambers JL
# 35                        Larigauderie A, Richards JH
#
#                                               Journal  Year Citations  \
# 0                The Science of the total environment  2024
# 1   Ying yong sheng tai xue bao = The journal of a...  2023
# 2                          Frontiers in plant science  2023
# 3                         Plants (Basel, Switzerland)  2022
# 4                           Plant, cell & environment  2022
# 5                                     Tree physiology  2022
# 6                                      Fungal biology  2021
# 7                The Science of the total environment  2021
# 8                         Plants (Basel, Switzerland)  2021
# 9                          Frontiers in plant science  2021
# 10                                    Tree physiology  2021
# 11                                         Mycorrhiza  2020
# 12                                    Tree physiology  2019
# 13                                The New phytologist  2019
# 14                                         Mycorrhiza  2018
# 15                                          Oecologia  2018
# 16                                    Tree physiology  2018
# 17                         Frontiers in plant science  2018
# 18                         Frontiers in plant science  2016
# 19                                   Annals of botany  2016
# 20                                           PloS one  2016
# 21                                    Tree physiology  2016
# 22                                    Tree physiology  2016
# 23                                The New phytologist  2015
# 24                                    Tree physiology  2014
# 25                                           PloS one  2014
# 26                                    Tree physiology  2012
# 27                                          Oecologia  2012
# 28                                          Oecologia  2009
# 29                                    Tree physiology  2007
# 30                                    Tree physiology  2003
# 31                                The New phytologist  2002
# 32                                    Tree physiology  2001
# 33                                          Oecologia  1997
# 34                                    Tree physiology  1996
# 35                                          Oecologia  1994
#
#                                        SearchTerm
# 0   roots AND phenology AND fine roots AND growth
# 1   roots AND phenology AND fine roots AND growth
# 2   roots AND phenology AND fine roots AND growth
# 3   roots AND phenology AND fine roots AND growth
# 4   roots AND phenology AND fine roots AND growth
# 5   roots AND phenology AND fine roots AND growth
# 6   roots AND phenology AND fine roots AND growth
# 7   roots AND phenology AND fine roots AND growth
# 8   roots AND phenology AND fine roots AND growth
# 9   roots AND phenology AND fine roots AND growth
# 10  roots AND phenology AND fine roots AND growth
# 11  roots AND phenology AND fine roots AND growth
# 12  roots AND phenology AND fine roots AND growth
# 13  roots AND phenology AND fine roots AND growth
# 14  roots AND phenology AND fine roots AND growth
# 15  roots AND phenology AND fine roots AND growth
# 16  roots AND phenology AND fine roots AND growth
# 17  roots AND phenology AND fine roots AND growth
# 18  roots AND phenology AND fine roots AND growth
# 19  roots AND phenology AND fine roots AND growth
# 20  roots AND phenology AND fine roots AND growth
# 21  roots AND phenology AND fine roots AND growth
# 22  roots AND phenology AND fine roots AND growth
# 23  roots AND phenology AND fine roots AND growth
# 24  roots AND phenology AND fine roots AND growth
# 25  roots AND phenology AND fine roots AND growth
# 26  roots AND phenology AND fine roots AND growth
# 27  roots AND phenology AND fine roots AND growth
# 28  roots AND phenology AND fine roots AND growth
# 29  roots AND phenology AND fine roots AND growth
# 30  roots AND phenology AND fine roots AND growth
# 31  roots AND phenology AND fine roots AND growth
# 32  roots AND phenology AND fine roots AND growth
# 33  roots AND phenology AND fine roots AND growth
# 34  roots AND phenology AND fine roots AND growth
# 35  roots AND phenology AND fine roots AND growth

# %%
import pandas as pd
from pymed import PubMed
import time

# Configuración de palabras clave y rango de años
keywords = ["roots AND phenology", "fine roots AND growth"]
start_year = 1990
end_year = 2025
max_results = 50  # Número máximo de resultados

# Función para buscar en PubMed
def search_pubmed(keywords, start_year, end_year, max_results=50):
    pubmed = PubMed(tool="PubMedSearcher", email="tu@email.com")  # Reemplaza con tu email
    query = ' AND '.join(keywords)
    results = pubmed.query(query, max_results=max_results)
    papers = []

    for result in results:
        # Obtiene la fecha de publicación
        pub_date = result.publication_date
        if pub_date:
            # Extrae el año de la fecha de publicación
            pub_year = int(pub_date[:4]) if isinstance(pub_date, str) else pub_date.year
        else:
            pub_year = None

        # Filtra por año de publicación
        if pub_year and start_year <= pub_year <= end_year:
            # Obtener el DOI o el ID de PubMed
            doi = result.doi if hasattr(result, 'doi') and result.doi else None
            link = doi if doi else result.pubmed_id  # Mostrar solo el DOI o el ID de PubMed

            paper = {
                'Title': result.title,
                'Link': link,  # Solo el DOI o el ID de PubMed
                'Abstract': result.abstract if result.abstract else "Resumen no disponible",
                'Authors': ', '.join([author['lastname'] + ' ' + author['initials'] for author in result.authors]) if result.authors else "Autores no disponibles",
                'Journal': result.journal if result.journal else "Revista no disponible",
                'Year': pub_year,
                'Citations': '',  # PubMed no proporciona citaciones directamente
                'SearchTerm': query  # Término de búsqueda utilizado
            }
            papers.append(paper)
            print(f"Publicación encontrada: {result.title}")  # Imprime cada publicación

    return papers

# Realizar búsqueda en PubMed
try:
    pubmed_papers = search_pubmed(keywords, start_year, end_year, max_results)
except Exception as e:
    print(f"Error durante la búsqueda: {e}")
    pubmed_papers = []

# Mostrar resultados
if pubmed_papers:
    df = pd.DataFrame(pubmed_papers)
    
    # Reordenar las columnas en el orden solicitado
    df = df[['Title', 'Link', 'Abstract', 'Authors', 'Journal', 'Year', 'Citations', 'SearchTerm']]
    
    print(df)

    # Guardar la tabla en un archivo CSV
    df.to_csv('pubmed_papers4.csv', index=False)
else:
    print("No se encontraron resultados o hubo un error en la búsqueda.")
# Out:
# Publicación encontrada: Above- and belowground phenology responses of subtropical Chinese fir (Cunninghamia lanceolata) to soil warming, precipitation exclusion and their interaction.
# Publicación encontrada: Effects of warming on fine root lifespan of forests: A review.
# Publicación encontrada: Divergent seasonal responses of above- and below-ground to environmental factors in alpine grassland.
# Publicación encontrada: Effects of Soil Water Shortage on Seedling Shoot and Root Growth of Saragolle Lucana Tetraploid Wheat (
# Publicación encontrada: Above- and belowground interplay: Canopy CO
# Publicación encontrada: Separating the effects of air and soil temperature on silver birch. Part I. Does soil temperature or resource competition determine the timing of root growth?
# Publicación encontrada: Eco-archaeological excavation techniques reveal snapshots of subterranean truffle growth.
# Publicación encontrada: Responses of root phenology in ecotypes of Eriophorum vaginatum to transplantation and warming in the Arctic.
# Publicación encontrada: Pulse Root Ideotype for Water Stress in Temperate Cropping System.
# Publicación encontrada: Remarkable Similarity in Timing of Absorptive Fine-Root Production Across 11 Diverse Temperate Tree Species in a Common Garden.
# Publicación encontrada: Dynamics of above- and belowground responses of silver birch saplings and soil gases to soil freezing and waterlogging during dormancy.
# Publicación encontrada: Prevalence and phenology of fine root endophyte colonization across populations of Lycopodiella inundata.
# Publicación encontrada: Climatic and physiological regulation of the bimodal xylem formation pattern in Pinus pinaster saplings.
# Publicación encontrada: Dwelling in the deep - strongly increased root growth and rooting depth enhance plant interactions with thawing permafrost soil.
# Publicación encontrada: Rapid temporal changes in root colonization by arbuscular mycorrhizal fungi and fine root endophytes, not dark septate endophytes, track plant activity and environment in an alpine ecosystem.
# Publicación encontrada: To spend or to save? Assessing energetic growth-storage tradeoffs in native and invasive woody plants.
# Publicación encontrada: Stand development and other intrinsic factors largely control fine-root dynamics with only subtle modifications from resource availability.
# Publicación encontrada: Phloem Girdling of Norway Spruce Alters Quantity and Quality of Wood Formation in Roots Particularly Under Drought.
# Publicación encontrada: Prolonged Soil Frost Affects Hydraulics and Phenology of Apple Trees.
# Publicación encontrada: Summer dormancy, drought survival and functional resource acquisition strategies in California perennial grasses.
# Publicación encontrada: Carbon Allocation into Different Fine-Root Classes of Young Abies alba Trees Is Affected More by Phenology than by Simulated Browsing.
# Publicación encontrada: Impact of treated wastewater on growth, respiration and hydraulic conductivity of citrus root systems in light and heavy soils.
# Publicación encontrada: Changes in fine-root production, phenology and spatial distribution in response to N application in irrigated sweet cherry trees.
# Publicación encontrada: The hidden season: growing season is 50% longer below than above ground along an arctic elevation gradient.
# Publicación encontrada: Seasonal changes in carbon and nitrogen compound concentrations in a Quercus petraea chronosequence.
# Publicación encontrada: Links between belowground and aboveground resource-related traits reveal species growth strategies that promote invasive advantages.
# Publicación encontrada: Intra-annual nutrient flux in Pinus taeda.
# Publicación encontrada: Dynamics of phreatophyte root growth relative to a seasonally fluctuating water table in a Mediterranean-type environment.
# Publicación encontrada: Elevated CO2 and O3 effects on fine-root survivorship in ponderosa pine mesocosms.
# Publicación encontrada: Dry-season leaf flushing of Enterolobium cyclocarpum (ear-pod tree): above- and below-ground phenology and water relations.
# Publicación encontrada: Genetic and environmental control of seasonal carbohydrate dynamics in trees of diverse Pinus sylvestris populations.
# Publicación encontrada: Below-ground carbon input to soil is controlled by nutrient availability and fine root dynamics in loblolly pine.
# Publicación encontrada: Water stress responses of seedlings of four Mediterranean oak species.
# Publicación encontrada: The influence of below ground herbivory and plant competition on growth and biomass allocation of purple loosestrife.
# Publicación encontrada: Seasonal branch and fine root growth of juvenile loblolly pine five growing seasons after fertilization.
# Publicación encontrada: Root proliferation characteristics of seven perennial arid-land grasses in nutrient-enriched microsites.
#                                                 Title  \
# 0   Above- and belowground phenology responses of ...
# 1   Effects of warming on fine root lifespan of fo...
# 2   Divergent seasonal responses of above- and bel...
# 3   Effects of Soil Water Shortage on Seedling Sho...
# 4         Above- and belowground interplay: Canopy CO
# 5   Separating the effects of air and soil tempera...
# 6   Eco-archaeological excavation techniques revea...
# 7   Responses of root phenology in ecotypes of Eri...
# 8   Pulse Root Ideotype for Water Stress in Temper...
# 9   Remarkable Similarity in Timing of Absorptive ...
# 10  Dynamics of above- and belowground responses o...
# 11  Prevalence and phenology of fine root endophyt...
# 12  Climatic and physiological regulation of the b...
# 13  Dwelling in the deep - strongly increased root...
# 14  Rapid temporal changes in root colonization by...
# 15  To spend or to save? Assessing energetic growt...
# 16  Stand development and other intrinsic factors ...
# 17  Phloem Girdling of Norway Spruce Alters Quanti...
# 18  Prolonged Soil Frost Affects Hydraulics and Ph...
# 19  Summer dormancy, drought survival and function...
# 20  Carbon Allocation into Different Fine-Root Cla...
# 21  Impact of treated wastewater on growth, respir...
# 22  Changes in fine-root production, phenology and...
# 23  The hidden season: growing season is 50% longe...
# 24  Seasonal changes in carbon and nitrogen compou...
# 25  Links between belowground and aboveground reso...
# 26         Intra-annual nutrient flux in Pinus taeda.
# 27  Dynamics of phreatophyte root growth relative ...
# 28  Elevated CO2 and O3 effects on fine-root survi...
# 29  Dry-season leaf flushing of Enterolobium cyclo...
# 30  Genetic and environmental control of seasonal ...
# 31  Below-ground carbon input to soil is controlle...
# 32  Water stress responses of seedlings of four Me...
# 33  The influence of below ground herbivory and pl...
# 34  Seasonal branch and fine root growth of juveni...
# 35  Root proliferation characteristics of seven pe...
#
#                                                  Link  \
# 0                     10.1016/j.scitotenv.2024.173147
# 1                     10.13287/j.1001-9332.202306.007
# 2   10.3389/fpls.2022.1091441\n10.3390/rs12030431\...
# 3   10.3390/plants11243492\n10.1088/1748-9326/aa72...
# 4                                   10.1111/pce.14519
# 5   10.1093/treephys/tpac092\n10.1007/978-1-4684-7...
# 6                        10.1016/j.funbio.2021.09.001
# 7                     10.1016/j.scitotenv.2021.149926
# 8   10.3390/plants10040692\n10.4141/CJPS06034\n10....
# 9   10.3389/fpls.2020.623722\n10.1111/nph.13111\n1...
# 10                           10.1093/treephys/tpab002
# 11  10.1007/s00572-020-00979-3\n10.1093/nar/25.17....
# 12                            10.1093/treephys/tpz099
# 13                                  10.1111/nph.15903
# 14                          10.1007/s00572-018-0863-7
# 15                          10.1007/s00442-018-4177-4
# 16                            10.1093/treephys/tpy033
# 17  10.3389/fpls.2018.00392\n10.1016/S0378-1127(01...
# 18  10.3389/fpls.2016.00867\n10.1111/j.1365-2435.2...
# 19                                 10.1093/aob/mcw109
# 20  10.1371/journal.pone.0154687\n10.1002/ece3.665...
# 21                            10.1093/treephys/tpw013
# 22  10.1093/treephys/tpw002\n10.1111/nph.13111\n10...
# 23                                  10.1111/nph.13655
# 24                            10.1093/treephys/tpu060
# 25                       10.1371/journal.pone.0104189
# 26                            10.1093/treephys/tps082
# 27                          10.1007/s00442-012-2381-1
# 28                          10.1007/s00442-009-1339-4
# 29                        10.1093/treephys/27.11.1561
# 30                         10.1093/treephys/20.12.837
# 31                   10.1046/j.1469-8137.2002.00393.x
# 32                        10.1093/treephys/20.16.1065
# 33                              10.1007/s004420050356
# 34                      10.1093/treephys/16.11-12.899
# 35                                 10.1007/BF00317089
#
#                                              Abstract  \
# 0   Plant phenology plays an important role in nut...
# 1   As an important parameter of forests growth, f...
# 2   Under current global warming, the relationship...
# 3   Ancient wheats may be a source of traits that ...
# 4   In forests, mycorrhizal fungi regulate carbon ...
# 5   The aboveground parts of boreal forest trees m...
# 6   Despite its status as a highly-prized and cove...
# 7   The effect of climate change on phenology and ...
# 8   Pulses are a key component of crop production ...
# 9   Long-term minirhizotron observations of absorp...
# 10  Winter precipitation and soil freeze-thaw even...
# 11  Mycorrhizal fungi are critical components of t...
# 12  Seasonality in tree cambial activity and xylem...
# 13  Climate-warming-induced permafrost thaw expose...
# 14  Fungal root endophytes play an important role ...
# 15  Many non-native woody plants invade low-light ...
# 16  Forest productivity depends on resource acquis...
# 17  Carbon (C) availability plays an essential rol...
# 18  Restoration of an adequate water supply in spr...
# 19  Evidence suggests drought severity is increasi...
# 20  Abies alba (European silver fir) was used to i...
# 21  Roots interact with soil properties and irriga...
# 22  Factors regulating fine-root growth are poorly...
# 23  There is compelling evidence from experiments ...
# 24  Forest productivity declines with tree age. Th...
# 25  Belowground processes are rarely considered in...
# 26  Intra-annual nutrient (nitrogen, phosphorus, p...
# 27  While seasonal redistribution of fine root bio...
# 28  Atmospheric carbon dioxide (CO(2)) and ozone (...
# 29  Above- and belowground phenology and water rel...
# 30  We explored environmental and genetic factors ...
# 31  •  Availability of growth limiting resources m...
# 32  Effects of water stress on phenology, growth, ...
# 33  Experiments investigating plant-herbivore inte...
# 34  In 1989, we established two replications of tw...
# 35  We compared root proliferation in fertilized m...
#
#                                               Authors  \
# 0   Qu Z, Lin C, Zhao H, Chen T, Yao X, Wang X, Ya...
# 1                   Liu YH, DU XL, Huang JX, Xiong DC
# 2                 Qin X, Nie X, Wang X, Hong J, Yan Y
# 3   Bochicchio R, Labella R, Rossi R, Perniola M, ...
# 4   Scartazza A, Sbrana C, D'Andrea E, Matteucci G...
# 5   Kilpeläinen J, Domisch T, Lehto T, Piirainen S...
# 6   Büntgen U, Peter M, Tegel W, Stobbe U, Elburg ...
# 7   Ma T, Parker T, Unger S, Gewirtzman J, Fetcher...
# 8   Rao S, Armstrong R, Silva-Perez V, Tefera AT, ...
# 9   Withington JM, Goebel M, Bułaj B, Oleksyn J, R...
# 10  Repo T, Domisch T, Roitto M, Kilpeläinen J, Wa...
# 11         Kowal J, Arrigoni E, Serra J, Bidartondo M
# 12  Garcia-Forner N, Vieira J, Nabais C, Carvalho ...
# 13  Blume-Werry G, Milbau A, Teuber LM, Johansson ...
# 14  Bueno de Mesquita CP, Martinez Del Río CM, Sud...
# 15                              Hinman ED, Fridley JD
# 16                              Coleman MD, Aubrey DP
# 17                      Rainer-Lethaus G, Oberhuber W
# 18                   Beikircher B, Mittmann C, Mayr S
# 19            Balachowski JA, Bristiel PM, Volaire FA
# 20                  Endrulat T, Buchmann N, Brunner I
# 21  Paudel I, Cohen S, Shaviv A, Bar-Tal A, Bernst...
# 22                             Artacho P, Bonomelli C
# 23     Blume-Werry G, Wilson SD, Kreyling J, Milbau A
# 24  Gilson A, Barthes L, Delpierre N, Dufrêne É, F...
# 25         Smith MS, Fridley JD, Goebel M, Bauerle TL
# 26  Albaugh TJ, Allen HL, Stape JL, Fox TR, Rubila...
# 27           Canham CA, Froend RH, Stock WD, Davies M
# 28       Phillips DL, Johnson MG, Tingey DT, Storm MJ
# 29    Rojas-Jiménez K, Holbrook NM, Gutiérrez-Soto MV
# 30  Oleksyn J, Zytkowiak R, Karolewski P, Reich PB...
# 31  King JS, Albaugh TJ, Allen HL, Buford M, Strai...
# 32         Fotelli MN, Radoglou KM, Constantinidou HI
# 33                     Nötzold R, Blossey B, Newton E
# 34     Sword MA, Gravatt DA, Faulkner PL, Chambers JL
# 35                        Larigauderie A, Richards JH
#
#                                               Journal  Year Citations  \
# 0                The Science of the total environment  2024
# 1   Ying yong sheng tai xue bao = The journal of a...  2023
# 2                          Frontiers in plant science  2023
# 3                         Plants (Basel, Switzerland)  2022
# 4                           Plant, cell & environment  2022
# 5                                     Tree physiology  2022
# 6                                      Fungal biology  2021
# 7                The Science of the total environment  2021
# 8                         Plants (Basel, Switzerland)  2021
# 9                          Frontiers in plant science  2021
# 10                                    Tree physiology  2021
# 11                                         Mycorrhiza  2020
# 12                                    Tree physiology  2019
# 13                                The New phytologist  2019
# 14                                         Mycorrhiza  2018
# 15                                          Oecologia  2018
# 16                                    Tree physiology  2018
# 17                         Frontiers in plant science  2018
# 18                         Frontiers in plant science  2016
# 19                                   Annals of botany  2016
# 20                                           PloS one  2016
# 21                                    Tree physiology  2016
# 22                                    Tree physiology  2016
# 23                                The New phytologist  2015
# 24                                    Tree physiology  2014
# 25                                           PloS one  2014
# 26                                    Tree physiology  2012
# 27                                          Oecologia  2012
# 28                                          Oecologia  2009
# 29                                    Tree physiology  2007
# 30                                    Tree physiology  2003
# 31                                The New phytologist  2002
# 32                                    Tree physiology  2001
# 33                                          Oecologia  1997
# 34                                    Tree physiology  1996
# 35                                          Oecologia  1994
#
#                                        SearchTerm
# 0   roots AND phenology AND fine roots AND growth
# 1   roots AND phenology AND fine roots AND growth
# 2   roots AND phenology AND fine roots AND growth
# 3   roots AND phenology AND fine roots AND growth
# 4   roots AND phenology AND fine roots AND growth
# 5   roots AND phenology AND fine roots AND growth
# 6   roots AND phenology AND fine roots AND growth
# 7   roots AND phenology AND fine roots AND growth
# 8   roots AND phenology AND fine roots AND growth
# 9   roots AND phenology AND fine roots AND growth
# 10  roots AND phenology AND fine roots AND growth
# 11  roots AND phenology AND fine roots AND growth
# 12  roots AND phenology AND fine roots AND growth
# 13  roots AND phenology AND fine roots AND growth
# 14  roots AND phenology AND fine roots AND growth
# 15  roots AND phenology AND fine roots AND growth
# 16  roots AND phenology AND fine roots AND growth
# 17  roots AND phenology AND fine roots AND growth
# 18  roots AND phenology AND fine roots AND growth
# 19  roots AND phenology AND fine roots AND growth
# 20  roots AND phenology AND fine roots AND growth
# 21  roots AND phenology AND fine roots AND growth
# 22  roots AND phenology AND fine roots AND growth
# 23  roots AND phenology AND fine roots AND growth
# 24  roots AND phenology AND fine roots AND growth
# 25  roots AND phenology AND fine roots AND growth
# 26  roots AND phenology AND fine roots AND growth
# 27  roots AND phenology AND fine roots AND growth
# 28  roots AND phenology AND fine roots AND growth
# 29  roots AND phenology AND fine roots AND growth
# 30  roots AND phenology AND fine roots AND growth
# 31  roots AND phenology AND fine roots AND growth
# 32  roots AND phenology AND fine roots AND growth
# 33  roots AND phenology AND fine roots AND growth
# 34  roots AND phenology AND fine roots AND growth
# 35  roots AND phenology AND fine roots AND growth

# %%
import pandas as pd
from pymed import PubMed
import time

# Configuración de palabras clave y rango de años
keywords = ["roots AND phenology", "fine roots AND growth"]
start_year = 1990
end_year = 2025
max_results = 50  # Número máximo de resultados

# Función para buscar en PubMed
def search_pubmed(keywords, start_year, end_year, max_results=50):
    pubmed = PubMed(tool="PubMedSearcher", email="tu@email.com")  # Reemplaza con tu email
    query = ' AND '.join(keywords)
    results = pubmed.query(query, max_results=max_results)
    papers = []

    for result in results:
        # Obtiene la fecha de publicación
        pub_date = result.publication_date
        if pub_date:
            # Extrae el año de la fecha de publicación
            pub_year = int(pub_date[:4]) if isinstance(pub_date, str) else pub_date.year
        else:
            pub_year = None

        # Filtra por año de publicación
        if pub_year and start_year <= pub_year <= end_year:
            # Obtener el DOI (solo el primero si es una lista)
            doi = result.doi if hasattr(result, 'doi') and result.doi else None
            if isinstance(doi, list):
                doi = doi[0]  # Tomar solo el primer DOI

            # Obtener el ID de PubMed (solo el primero si es una lista)
            pubmed_id = result.pubmed_id if hasattr(result, 'pubmed_id') else None
            if isinstance(pubmed_id, list):
                pubmed_id = pubmed_id[0]  # Tomar solo el primer ID

            # Seleccionar el enlace (prioridad al DOI)
            if doi:
                link = f"https://doi.org/{doi}"
            elif pubmed_id:
                link = f"https://pubmed.ncbi.nlm.nih.gov/{pubmed_id}"
            else:
                link = ""  # Dejar vacío si no hay DOI ni PubMed ID

            paper = {
                'Title': result.title,
                'Link': link,  # Solo un enlace por artículo
                'Abstract': result.abstract if result.abstract else "Resumen no disponible",
                'Authors': ', '.join([author['lastname'] + ' ' + author['initials'] for author in result.authors]) if result.authors else "Autores no disponibles",
                'Journal': result.journal if result.journal else "Revista no disponible",
                'Year': pub_year,
                'Citations': '',  # PubMed no proporciona citaciones directamente
                'SearchTerm': query  # Término de búsqueda utilizado
            }
            papers.append(paper)
            print(f"Publicación encontrada: {result.title}")  # Imprime cada publicación

    return papers

# Realizar búsqueda en PubMed
try:
    pubmed_papers = search_pubmed(keywords, start_year, end_year, max_results)
except Exception as e:
    print(f"Error durante la búsqueda: {e}")
    pubmed_papers = []

# Mostrar resultados
if pubmed_papers:
    df = pd.DataFrame(pubmed_papers)
    
    # Reordenar las columnas en el orden solicitado
    df = df[['Title', 'Link', 'Abstract', 'Authors', 'Journal', 'Year', 'Citations', 'SearchTerm']]
    
    print(df)

    # Guardar la tabla en un archivo CSV
    df.to_csv('pubmed_papers9.csv', index=False)
else:
    print("No se encontraron resultados o hubo un error en la búsqueda.")
# Out:
# Publicación encontrada: Above- and belowground phenology responses of subtropical Chinese fir (Cunninghamia lanceolata) to soil warming, precipitation exclusion and their interaction.
# Publicación encontrada: Effects of warming on fine root lifespan of forests: A review.
# Publicación encontrada: Divergent seasonal responses of above- and below-ground to environmental factors in alpine grassland.
# Publicación encontrada: Effects of Soil Water Shortage on Seedling Shoot and Root Growth of Saragolle Lucana Tetraploid Wheat (
# Publicación encontrada: Above- and belowground interplay: Canopy CO
# Publicación encontrada: Separating the effects of air and soil temperature on silver birch. Part I. Does soil temperature or resource competition determine the timing of root growth?
# Publicación encontrada: Eco-archaeological excavation techniques reveal snapshots of subterranean truffle growth.
# Publicación encontrada: Responses of root phenology in ecotypes of Eriophorum vaginatum to transplantation and warming in the Arctic.
# Publicación encontrada: Pulse Root Ideotype for Water Stress in Temperate Cropping System.
# Publicación encontrada: Remarkable Similarity in Timing of Absorptive Fine-Root Production Across 11 Diverse Temperate Tree Species in a Common Garden.
# Publicación encontrada: Dynamics of above- and belowground responses of silver birch saplings and soil gases to soil freezing and waterlogging during dormancy.
# Publicación encontrada: Prevalence and phenology of fine root endophyte colonization across populations of Lycopodiella inundata.
# Publicación encontrada: Climatic and physiological regulation of the bimodal xylem formation pattern in Pinus pinaster saplings.
# Publicación encontrada: Dwelling in the deep - strongly increased root growth and rooting depth enhance plant interactions with thawing permafrost soil.
# Publicación encontrada: Rapid temporal changes in root colonization by arbuscular mycorrhizal fungi and fine root endophytes, not dark septate endophytes, track plant activity and environment in an alpine ecosystem.
# Publicación encontrada: To spend or to save? Assessing energetic growth-storage tradeoffs in native and invasive woody plants.
# Publicación encontrada: Stand development and other intrinsic factors largely control fine-root dynamics with only subtle modifications from resource availability.
# Publicación encontrada: Phloem Girdling of Norway Spruce Alters Quantity and Quality of Wood Formation in Roots Particularly Under Drought.
# Publicación encontrada: Prolonged Soil Frost Affects Hydraulics and Phenology of Apple Trees.
# Publicación encontrada: Summer dormancy, drought survival and functional resource acquisition strategies in California perennial grasses.
# Publicación encontrada: Carbon Allocation into Different Fine-Root Classes of Young Abies alba Trees Is Affected More by Phenology than by Simulated Browsing.
# Publicación encontrada: Impact of treated wastewater on growth, respiration and hydraulic conductivity of citrus root systems in light and heavy soils.
# Publicación encontrada: Changes in fine-root production, phenology and spatial distribution in response to N application in irrigated sweet cherry trees.
# Publicación encontrada: The hidden season: growing season is 50% longer below than above ground along an arctic elevation gradient.
# Publicación encontrada: Seasonal changes in carbon and nitrogen compound concentrations in a Quercus petraea chronosequence.
# Publicación encontrada: Links between belowground and aboveground resource-related traits reveal species growth strategies that promote invasive advantages.
# Publicación encontrada: Intra-annual nutrient flux in Pinus taeda.
# Publicación encontrada: Dynamics of phreatophyte root growth relative to a seasonally fluctuating water table in a Mediterranean-type environment.
# Publicación encontrada: Elevated CO2 and O3 effects on fine-root survivorship in ponderosa pine mesocosms.
# Publicación encontrada: Dry-season leaf flushing of Enterolobium cyclocarpum (ear-pod tree): above- and below-ground phenology and water relations.
# Publicación encontrada: Genetic and environmental control of seasonal carbohydrate dynamics in trees of diverse Pinus sylvestris populations.
# Publicación encontrada: Below-ground carbon input to soil is controlled by nutrient availability and fine root dynamics in loblolly pine.
# Publicación encontrada: Water stress responses of seedlings of four Mediterranean oak species.
# Publicación encontrada: The influence of below ground herbivory and plant competition on growth and biomass allocation of purple loosestrife.
# Publicación encontrada: Seasonal branch and fine root growth of juvenile loblolly pine five growing seasons after fertilization.
# Publicación encontrada: Root proliferation characteristics of seven perennial arid-land grasses in nutrient-enriched microsites.
#                                                 Title  \
# 0   Above- and belowground phenology responses of ...
# 1   Effects of warming on fine root lifespan of fo...
# 2   Divergent seasonal responses of above- and bel...
# 3   Effects of Soil Water Shortage on Seedling Sho...
# 4         Above- and belowground interplay: Canopy CO
# 5   Separating the effects of air and soil tempera...
# 6   Eco-archaeological excavation techniques revea...
# 7   Responses of root phenology in ecotypes of Eri...
# 8   Pulse Root Ideotype for Water Stress in Temper...
# 9   Remarkable Similarity in Timing of Absorptive ...
# 10  Dynamics of above- and belowground responses o...
# 11  Prevalence and phenology of fine root endophyt...
# 12  Climatic and physiological regulation of the b...
# 13  Dwelling in the deep - strongly increased root...
# 14  Rapid temporal changes in root colonization by...
# 15  To spend or to save? Assessing energetic growt...
# 16  Stand development and other intrinsic factors ...
# 17  Phloem Girdling of Norway Spruce Alters Quanti...
# 18  Prolonged Soil Frost Affects Hydraulics and Ph...
# 19  Summer dormancy, drought survival and function...
# 20  Carbon Allocation into Different Fine-Root Cla...
# 21  Impact of treated wastewater on growth, respir...
# 22  Changes in fine-root production, phenology and...
# 23  The hidden season: growing season is 50% longe...
# 24  Seasonal changes in carbon and nitrogen compou...
# 25  Links between belowground and aboveground reso...
# 26         Intra-annual nutrient flux in Pinus taeda.
# 27  Dynamics of phreatophyte root growth relative ...
# 28  Elevated CO2 and O3 effects on fine-root survi...
# 29  Dry-season leaf flushing of Enterolobium cyclo...
# 30  Genetic and environmental control of seasonal ...
# 31  Below-ground carbon input to soil is controlle...
# 32  Water stress responses of seedlings of four Me...
# 33  The influence of below ground herbivory and pl...
# 34  Seasonal branch and fine root growth of juveni...
# 35  Root proliferation characteristics of seven pe...
#
#                                                  Link  \
# 0     https://doi.org/10.1016/j.scitotenv.2024.173147
# 1     https://doi.org/10.13287/j.1001-9332.202306.007
# 2   https://doi.org/10.3389/fpls.2022.1091441\n10....
# 3   https://doi.org/10.3390/plants11243492\n10.108...
# 4                   https://doi.org/10.1111/pce.14519
# 5   https://doi.org/10.1093/treephys/tpac092\n10.1...
# 6        https://doi.org/10.1016/j.funbio.2021.09.001
# 7     https://doi.org/10.1016/j.scitotenv.2021.149926
# 8   https://doi.org/10.3390/plants10040692\n10.414...
# 9   https://doi.org/10.3389/fpls.2020.623722\n10.1...
# 10           https://doi.org/10.1093/treephys/tpab002
# 11  https://doi.org/10.1007/s00572-020-00979-3\n10...
# 12            https://doi.org/10.1093/treephys/tpz099
# 13                  https://doi.org/10.1111/nph.15903
# 14          https://doi.org/10.1007/s00572-018-0863-7
# 15          https://doi.org/10.1007/s00442-018-4177-4
# 16            https://doi.org/10.1093/treephys/tpy033
# 17  https://doi.org/10.3389/fpls.2018.00392\n10.10...
# 18  https://doi.org/10.3389/fpls.2016.00867\n10.11...
# 19                 https://doi.org/10.1093/aob/mcw109
# 20  https://doi.org/10.1371/journal.pone.0154687\n...
# 21            https://doi.org/10.1093/treephys/tpw013
# 22  https://doi.org/10.1093/treephys/tpw002\n10.11...
# 23                  https://doi.org/10.1111/nph.13655
# 24            https://doi.org/10.1093/treephys/tpu060
# 25       https://doi.org/10.1371/journal.pone.0104189
# 26            https://doi.org/10.1093/treephys/tps082
# 27          https://doi.org/10.1007/s00442-012-2381-1
# 28          https://doi.org/10.1007/s00442-009-1339-4
# 29        https://doi.org/10.1093/treephys/27.11.1561
# 30         https://doi.org/10.1093/treephys/20.12.837
# 31   https://doi.org/10.1046/j.1469-8137.2002.00393.x
# 32        https://doi.org/10.1093/treephys/20.16.1065
# 33              https://doi.org/10.1007/s004420050356
# 34      https://doi.org/10.1093/treephys/16.11-12.899
# 35                 https://doi.org/10.1007/BF00317089
#
#                                              Abstract  \
# 0   Plant phenology plays an important role in nut...
# 1   As an important parameter of forests growth, f...
# 2   Under current global warming, the relationship...
# 3   Ancient wheats may be a source of traits that ...
# 4   In forests, mycorrhizal fungi regulate carbon ...
# 5   The aboveground parts of boreal forest trees m...
# 6   Despite its status as a highly-prized and cove...
# 7   The effect of climate change on phenology and ...
# 8   Pulses are a key component of crop production ...
# 9   Long-term minirhizotron observations of absorp...
# 10  Winter precipitation and soil freeze-thaw even...
# 11  Mycorrhizal fungi are critical components of t...
# 12  Seasonality in tree cambial activity and xylem...
# 13  Climate-warming-induced permafrost thaw expose...
# 14  Fungal root endophytes play an important role ...
# 15  Many non-native woody plants invade low-light ...
# 16  Forest productivity depends on resource acquis...
# 17  Carbon (C) availability plays an essential rol...
# 18  Restoration of an adequate water supply in spr...
# 19  Evidence suggests drought severity is increasi...
# 20  Abies alba (European silver fir) was used to i...
# 21  Roots interact with soil properties and irriga...
# 22  Factors regulating fine-root growth are poorly...
# 23  There is compelling evidence from experiments ...
# 24  Forest productivity declines with tree age. Th...
# 25  Belowground processes are rarely considered in...
# 26  Intra-annual nutrient (nitrogen, phosphorus, p...
# 27  While seasonal redistribution of fine root bio...
# 28  Atmospheric carbon dioxide (CO(2)) and ozone (...
# 29  Above- and belowground phenology and water rel...
# 30  We explored environmental and genetic factors ...
# 31  •  Availability of growth limiting resources m...
# 32  Effects of water stress on phenology, growth, ...
# 33  Experiments investigating plant-herbivore inte...
# 34  In 1989, we established two replications of tw...
# 35  We compared root proliferation in fertilized m...
#
#                                               Authors  \
# 0   Qu Z, Lin C, Zhao H, Chen T, Yao X, Wang X, Ya...
# 1                   Liu YH, DU XL, Huang JX, Xiong DC
# 2                 Qin X, Nie X, Wang X, Hong J, Yan Y
# 3   Bochicchio R, Labella R, Rossi R, Perniola M, ...
# 4   Scartazza A, Sbrana C, D'Andrea E, Matteucci G...
# 5   Kilpeläinen J, Domisch T, Lehto T, Piirainen S...
# 6   Büntgen U, Peter M, Tegel W, Stobbe U, Elburg ...
# 7   Ma T, Parker T, Unger S, Gewirtzman J, Fetcher...
# 8   Rao S, Armstrong R, Silva-Perez V, Tefera AT, ...
# 9   Withington JM, Goebel M, Bułaj B, Oleksyn J, R...
# 10  Repo T, Domisch T, Roitto M, Kilpeläinen J, Wa...
# 11         Kowal J, Arrigoni E, Serra J, Bidartondo M
# 12  Garcia-Forner N, Vieira J, Nabais C, Carvalho ...
# 13  Blume-Werry G, Milbau A, Teuber LM, Johansson ...
# 14  Bueno de Mesquita CP, Martinez Del Río CM, Sud...
# 15                              Hinman ED, Fridley JD
# 16                              Coleman MD, Aubrey DP
# 17                      Rainer-Lethaus G, Oberhuber W
# 18                   Beikircher B, Mittmann C, Mayr S
# 19            Balachowski JA, Bristiel PM, Volaire FA
# 20                  Endrulat T, Buchmann N, Brunner I
# 21  Paudel I, Cohen S, Shaviv A, Bar-Tal A, Bernst...
# 22                             Artacho P, Bonomelli C
# 23     Blume-Werry G, Wilson SD, Kreyling J, Milbau A
# 24  Gilson A, Barthes L, Delpierre N, Dufrêne É, F...
# 25         Smith MS, Fridley JD, Goebel M, Bauerle TL
# 26  Albaugh TJ, Allen HL, Stape JL, Fox TR, Rubila...
# 27           Canham CA, Froend RH, Stock WD, Davies M
# 28       Phillips DL, Johnson MG, Tingey DT, Storm MJ
# 29    Rojas-Jiménez K, Holbrook NM, Gutiérrez-Soto MV
# 30  Oleksyn J, Zytkowiak R, Karolewski P, Reich PB...
# 31  King JS, Albaugh TJ, Allen HL, Buford M, Strai...
# 32         Fotelli MN, Radoglou KM, Constantinidou HI
# 33                     Nötzold R, Blossey B, Newton E
# 34     Sword MA, Gravatt DA, Faulkner PL, Chambers JL
# 35                        Larigauderie A, Richards JH
#
#                                               Journal  Year Citations  \
# 0                The Science of the total environment  2024
# 1   Ying yong sheng tai xue bao = The journal of a...  2023
# 2                          Frontiers in plant science  2023
# 3                         Plants (Basel, Switzerland)  2022
# 4                           Plant, cell & environment  2022
# 5                                     Tree physiology  2022
# 6                                      Fungal biology  2021
# 7                The Science of the total environment  2021
# 8                         Plants (Basel, Switzerland)  2021
# 9                          Frontiers in plant science  2021
# 10                                    Tree physiology  2021
# 11                                         Mycorrhiza  2020
# 12                                    Tree physiology  2019
# 13                                The New phytologist  2019
# 14                                         Mycorrhiza  2018
# 15                                          Oecologia  2018
# 16                                    Tree physiology  2018
# 17                         Frontiers in plant science  2018
# 18                         Frontiers in plant science  2016
# 19                                   Annals of botany  2016
# 20                                           PloS one  2016
# 21                                    Tree physiology  2016
# 22                                    Tree physiology  2016
# 23                                The New phytologist  2015
# 24                                    Tree physiology  2014
# 25                                           PloS one  2014
# 26                                    Tree physiology  2012
# 27                                          Oecologia  2012
# 28                                          Oecologia  2009
# 29                                    Tree physiology  2007
# 30                                    Tree physiology  2003
# 31                                The New phytologist  2002
# 32                                    Tree physiology  2001
# 33                                          Oecologia  1997
# 34                                    Tree physiology  1996
# 35                                          Oecologia  1994
#
#                                        SearchTerm
# 0   roots AND phenology AND fine roots AND growth
# 1   roots AND phenology AND fine roots AND growth
# 2   roots AND phenology AND fine roots AND growth
# 3   roots AND phenology AND fine roots AND growth
# 4   roots AND phenology AND fine roots AND growth
# 5   roots AND phenology AND fine roots AND growth
# 6   roots AND phenology AND fine roots AND growth
# 7   roots AND phenology AND fine roots AND growth
# 8   roots AND phenology AND fine roots AND growth
# 9   roots AND phenology AND fine roots AND growth
# 10  roots AND phenology AND fine roots AND growth
# 11  roots AND phenology AND fine roots AND growth
# 12  roots AND phenology AND fine roots AND growth
# 13  roots AND phenology AND fine roots AND growth
# 14  roots AND phenology AND fine roots AND growth
# 15  roots AND phenology AND fine roots AND growth
# 16  roots AND phenology AND fine roots AND growth
# 17  roots AND phenology AND fine roots AND growth
# 18  roots AND phenology AND fine roots AND growth
# 19  roots AND phenology AND fine roots AND growth
# 20  roots AND phenology AND fine roots AND growth
# 21  roots AND phenology AND fine roots AND growth
# 22  roots AND phenology AND fine roots AND growth
# 23  roots AND phenology AND fine roots AND growth
# 24  roots AND phenology AND fine roots AND growth
# 25  roots AND phenology AND fine roots AND growth
# 26  roots AND phenology AND fine roots AND growth
# 27  roots AND phenology AND fine roots AND growth
# 28  roots AND phenology AND fine roots AND growth
# 29  roots AND phenology AND fine roots AND growth
# 30  roots AND phenology AND fine roots AND growth
# 31  roots AND phenology AND fine roots AND growth
# 32  roots AND phenology AND fine roots AND growth
# 33  roots AND phenology AND fine roots AND growth
# 34  roots AND phenology AND fine roots AND growth
# 35  roots AND phenology AND fine roots AND growth

# %%
import requests
import pandas as pd

# API  Scopus
api_key = '9dd60b7a5ea00b072d913b64dc700aaa'  
base_url = 'https://api.elsevier.com/content/search/scopus'


keywords = ["roots AND phenology", "fine roots AND growth"]
start_year = 1990
end_year = 2025
query = ' AND '.join(keywords)

# Parameters
params = {
    'query': f'TITLE-ABS-KEY({query}) AND PUBYEAR > {start_year} AND PUBYEAR < {end_year}',
    'apiKey': api_key,
    'count': 25,  
    'start': 0     
}

def search_scopus(params, max_results=300):
    papers = []
    while len(papers) < max_results:
        response = requests.get(base_url, params=params)
        if response.status_code != 200:
            raise Exception(f"Error: {response.status_code} - {response.text}")
        
        data = response.json()
        results = data.get('search-results', {}).get('entry', [])
        
        for result in results:
            # 
            doi = result.get('prism:doi', '')
            link = f'https://doi.org/{doi}' if doi else result.get('prism:url', '')  
            paper = {
                'Title': result.get('dc:title', ''),
                'Link': link,  
                'Abstract': result.get('dc:description', ''),  
                'Authors': result.get('dc:creator', ''),
                'Journal': result.get('prism:publicationName', ''),
                'Year': result.get('prism:coverDate', '')[:4],  
                'Citations': result.get('citedby-count', 0),  
                'SearchTerm': query  
            }
            papers.append(paper)
        
        
        if len(results) < params['count']:
            break
        
        
        params['start'] += params['count']
    
    return papers[:max_results]  #limits


scopus_papers = search_scopus(params, max_results=200)


df_scopus = pd.DataFrame(scopus_papers)

df_scopus = df_scopus[['Title', 'Link', 'Abstract', 'Authors', 'Journal', 'Year', 'Citations', 'SearchTerm']]


print(df_scopus)

# Save results
df_scopus.to_csv('scopus_papers_4.csv', index=False)
# Out:
#                                                  Title  \
# 0    In situ soil imaging, a tool for monitoring th...
# 1    Above- and belowground phenology responses of ...
# 2    Monitoring Grassland Variation in a Typical Ar...
# 3    A systematic review of studies on fine and coa...
# 4    Effects of warming on fine root phenology of f...
# ..                                                 ...
# 117  The effect of nitrogen fertilization on the ph...
# 118  Root proliferation characteristics of seven pe...
# 119  Fine root growth phenology, production, and tu...
# 120  Environmental constraints on the structure and...
# 121  The Dutch Acidification Systems (DAS) model: T...
#
#                                                   Link Abstract  \
# 0           https://doi.org/10.1007/s00374-024-01851-8
# 1      https://doi.org/10.1016/j.scitotenv.2024.173147
# 2                   https://doi.org/10.3390/rs16071222
# 3            https://doi.org/10.3389/ffgc.2024.1322087
# 4              https://doi.org/10.17521/cjpe.2022.0326
# ..                                                 ...      ...
# 117                 https://doi.org/10.1007/BF00011002
# 118                 https://doi.org/10.1007/BF00317089
# 119                 https://doi.org/10.1007/BF01416099
# 120  https://api.elsevier.com/content/abstract/scop...
# 121      https://doi.org/10.1016/S0166-1116(08)70142-0
#
#              Authors                                            Journal  Year  \
# 0          Belaud E.                     Biology and Fertility of Soils  2024
# 1              Qu Z.                   Science of the Total Environment  2024
# 2              Li M.                                     Remote Sensing  2024
# 3        Fantozzi D.             Frontiers in Forests and Global Change  2024
# 4          Chen X.Y.                   Chinese Journal of Plant Ecology  2023
# ..               ...                                                ...   ...
# 117       Weber E.P.                                     Plant and Soil  1996
# 118  Larigauderie A.                                          Oecologia  1994
# 119       Burke M.K.                                     Plant and Soil  1994
# 120         Gholz H.  Environmental constraints on the structure and...  1994
# 121  van Grinsven J.                   Studies in Environmental Science  1992
#
#     Citations                                     SearchTerm
# 0           0  roots AND phenology AND fine roots AND growth
# 1           3  roots AND phenology AND fine roots AND growth
# 2           2  roots AND phenology AND fine roots AND growth
# 3           2  roots AND phenology AND fine roots AND growth
# 4           0  roots AND phenology AND fine roots AND growth
# ..        ...                                            ...
# 117        13  roots AND phenology AND fine roots AND growth
# 118        46  roots AND phenology AND fine roots AND growth
# 119       269  roots AND phenology AND fine roots AND growth
# 120         7  roots AND phenology AND fine roots AND growth
# 121         0  roots AND phenology AND fine roots AND growth
#
# [122 rows x 8 columns]
